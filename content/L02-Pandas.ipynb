# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Pandas" data-toc-modified-id="Pandas-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Pandas</a></span><ul class="toc-item"><li><span><a href="#Serie" data-toc-modified-id="Serie-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Serie</a></span></li><li><span><a href="#Visualizzione-grafica-di-una-serie" data-toc-modified-id="Visualizzione-grafica-di-una-serie-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Visualizzione grafica di una serie</a></span></li><li><span><a href="#Operazioni-con-le-serie" data-toc-modified-id="Operazioni-con-le-serie-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Operazioni con le serie</a></span></li><li><span><a href="#Dataframe" data-toc-modified-id="Dataframe-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Dataframe</a></span></li></ul></li></ul></div>

# %% [markdown]
# <div class="header">
# D. Malchiodi, Superhero data science. Vol 1: probabilità e statistica: Pandas.
# </div>
# <hr style="width: 90%;" align="left" />

# %% [markdown]
# <div id="h-0"></div>
#
# # Pandas
# Vedremo come la libreria pandas faciliti le operazioni viste finora per caricare dati, organizzarli in opportune strutture e analizzarli. Per poter procedere dobbiamo ricaricare le librerie usate finora, nonché il file `heroes.csv`. Useremo anche la _matplotlib magic_ che ci permette di visualizzare i grafici direttamente nel notebook.

# %%
# %matplotlib inline

import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

plt.style.use('fivethirtyeight')
plt.rc('figure', figsize=(5.0, 2.0))

with open('data/heroes.csv', 'r') as heroes_file:
  heroes_reader = csv.reader(heroes_file, delimiter=';', quotechar='"')
  heroes = list(heroes_reader)[1:]
# Out:
# [['Name',
#   'Identity',
#   'Birth place',
#   'Publisher',
#   'Height',
#   'Weight',
#   'Gender',
#   'First appearance',
#   'Eye color',
#   'Hair color',
#   'Strength',
#   'Intelligence'],
#  ['A-Bomb',
#   'Richard Milhouse Jones',
#   'Scarsdale, Arizona',
#   'Marvel Comics',
#   '203.21000000000001',
#   '441.94999999999999',
#   'M',
#   '2008',
#   'Yellow',
#   'No Hair',
#   '100',
#   'moderate'],
#  ['Abraxas',
#   'Abraxas',
#   'Within Eternity ',
#   'Marvel Comics',
#   '',
#   '',
#   'M',
#   '',
#   'Blue',
#   'Black',
#   '100',
#   'high'],
#  ['Abomination',
#   'Emil Blonsky',
#   'Zagreb, Yugoslavia',
#   'Marvel Comics',
#   '203.03999999999999',
#   '441.98000000000002',
#   'M',
#   '',
#   'Green',
#   'No Hair',
#   '80',
#   'good'],
#  ['Adam Monroe',
#   '',
#   '',
#   'NBC - Heroes',
#   '',
#   '',
#   'M',
#   '',
#   'Blue',
#   'Blond',
#   '10',
#   'good'],
#  ['Agent 13',
#   'Sharon Carter',
#   '',
#   'Marvel Comics',
#   '173.41',
#   '61.030000000000001',
#   'F',
#   '',
#   'Blue',
#   'Blond',
#   '',
#   ''],
#  ['Air-Walker',
#   'Gabriel Lan',
#   'Xandar, a planet in the Tranta system, Andromeda galaxy',
#   'Marvel Comics',
#   '188.59',
#   '108.23',
#   'M',
#   '',
#   'Blue',
#   'White',
#   '85',
#   'average'],
#  ['Agent Bob',
#   'Bob',
#   '',
#   'Marvel Comics',
#   '178.25',
#   '81.450000000000003',
#   'M',
#   '2007',
#   'Brown',
#   'Brown',
#   '10',
#   'low'],
#  ['Abe Sapien',
#   'Abraham Sapien',
#   '',
#   'Dark Horse Comics',
#   '191.24000000000001',
#   '65.349999999999994',
#   'M',
#   '1993',
#   'Blue',
#   'No Hair',
#   '30',
#   'high'],
#  ['Abin Sur',
#   '',
#   'Ungara',
#   'DC Comics',
#   '185.52000000000001',
#   '90.900000000000006',
#   'M',
#   '1959',
#   'Blue',
#   'No Hair',
#   '90',
#   'average'],
#  ['Angela', '', '', 'Image Comics', '', '', 'F', '', '', '', '100', 'high'],
#  ['Animal Man',
#   'Bernhard Baker',
#   '',
#   'DC Comics',
#   '183.80000000000001',
#   '83.390000000000001',
#   'M',
#   '1965',
#   'Blue',
#   'Blond',
#   '50',
#   'average'],
#  ['Agent Zero',
#   'Christoph Nord',
#   'Unrevealed location in former East Germany ',
#   'Marvel Comics',
#   '191.28999999999999',
#   '104.17',
#   'M',
#   '',
#   '',
#   '',
#   '30',
#   'good'],
#  ['Colin Wagner',
#   '',
#   '',
#   'HarperCollins',
#   '',
#   '',
#   'M',
#   '',
#   'Grey',
#   'Brown',
#   '',
#   ''],
#  ['Angel Dust',
#   'Christina',
#   '',
#   'Marvel Comics',
#   '165.78',
#   '57.210000000000001',
#   'F',
#   '',
#   'Yellow',
#   'Black',
#   '55',
#   'moderate'],
#  ['Angel Salvadore',
#   'Angel Salvadore Bohusk',
#   '',
#   'Marvel Comics',
#   '163.56999999999999',
#   '54.670000000000002',
#   'F',
#   '2001',
#   'Brown',
#   'Black',
#   '10',
#   'moderate'],
#  ['Zoom',
#   'Hunter Zolomon',
#   '',
#   'DC Comics',
#   '185.90000000000001',
#   '81.930000000000007',
#   'M',
#   '',
#   'Red',
#   'Brown',
#   '10',
#   'average'],
#  ['Lady Deathstrike',
#   'Yuriko Oyama',
#   'Osaka, Japan',
#   'Marvel Comics',
#   '175.84999999999999',
#   '58.890000000000001',
#   'F',
#   '1985',
#   'Brown',
#   'Black',
#   '30',
#   'good'],
#  ['Yoda',
#   'Yoda',
#   '',
#   'George Lucas',
#   '66.290000000000006',
#   '17.010000000000002',
#   'M',
#   '1980',
#   'Brown',
#   'White',
#   '55',
#   'high'],
#  ['Zatanna',
#   'Zatanna Zatara',
#   '',
#   'DC Comics',
#   '170.28999999999999',
#   '57.770000000000003',
#   'F',
#   '',
#   'Blue',
#   'Black',
#   '10',
#   'high'],
#  ['Yellowjacket II',
#   'Rita DeMara',
#   '',
#   'Marvel Comics',
#   '165.58000000000001',
#   '52.359999999999999',
#   'F',
#   '',
#   'Blue',
#   'Strawberry Blond',
#   '10',
#   'average'],
#  ['Yellowjacket',
#   'Hank Pym',
#   'Elmsford, New York',
#   'Marvel Comics',
#   '183.03',
#   '83.709999999999994',
#   'M',
#   '',
#   'Blue',
#   'Blond',
#   '10',
#   'high'],
#  ['Yellow Claw',
#   '',
#   'Somewhere in mainland China',
#   'Marvel Comics',
#   '188.40000000000001',
#   '95.090000000000003',
#   'M',
#   '',
#   'Blue',
#   'No Hair',
#   '',
#   ''],
#  ['Absorbing Man',
#   'Carl Creel',
#   'New York City, New York',
#   'Marvel Comics',
#   '193.36000000000001',
#   '122.28',
#   'M',
#   '1964',
#   'Blue',
#   'No Hair',
#   '80',
#   'moderate'],
#  ['X-Man',
#   'Nate Grey',
#   'American Northeast of Earth-295 ',
#   'Marvel Comics',
#   '175.81999999999999',
#   '61.799999999999997',
#   'M',
#   '1995',
#   'Blue',
#   'Brown',
#   '55',
#   'high'],
#  ['X-23',
#   'Laura Kinney',
#   'The Facility, location unrevealed ',
#   'Marvel Comics',
#   '155.61000000000001',
#   '50.390000000000001',
#   'F',
#   '',
#   'Green',
#   'Black',
#   '25',
#   'good'],
#  ['Wondra', '', '', 'Marvel Comics', '', '', 'F', '', '', '', '', ''],
#  ['Adam Strange',
#   'Adam Strange',
#   'Chicago, Illinois',
#   'DC Comics',
#   '185.09999999999999',
#   '88.920000000000002',
#   'M',
#   '1986',
#   'Blue',
#   'Blond',
#   '10',
#   'good'],
#  ['Wonder Girl',
#   'Cassandra Elizabeth Sandsmark',
#   '',
#   'DC Comics',
#   '165.74000000000001',
#   '51.329999999999998',
#   'F',
#   '1996',
#   'Blue',
#   'Blond',
#   '90',
#   'good'],
#  ['Wonder Woman',
#   'Diana Prince',
#   'Themyscira',
#   'DC Comics',
#   '183.13',
#   '74.739999999999995',
#   'F',
#   '1941',
#   'Blue',
#   'Black',
#   '100',
#   'high'],
#  ['Wolverine',
#   'Logan',
#   'Alberta, Canada',
#   'Marvel Comics',
#   '160.69999999999999',
#   '135.21000000000001',
#   'M',
#   '',
#   'Blue',
#   'Black',
#   '35',
#   'good'],
#  ['Ymir',
#   'Ymir',
#   'Niffleheim',
#   'Marvel Comics',
#   '304.63',
#   '',
#   'M',
#   '',
#   'White',
#   'No Hair',
#   '100',
#   'average'],
#  ['Wiz Kid',
#   'Takashi Matsuya',
#   'Place of birth unknown',
#   'Marvel Comics',
#   '140.86000000000001',
#   '39.640000000000001',
#   '',
#   '',
#   'Brown',
#   'Black',
#   '',
#   ''],
#  ['Wolfsbane',
#   'Rahne Sinclair',
#   'Somewhere in Ross and Cromarty, Scotland',
#   'Marvel Comics',
#   '366.33999999999997',
#   '473.75999999999999',
#   'F',
#   '',
#   'Green',
#   'Auburn',
#   '20',
#   'moderate'],
#  ['White Queen',
#   'Emma Grace Frost',
#   'Boston, Massachusetts',
#   'Marvel Comics',
#   '178.87',
#   '65.870000000000005',
#   'F',
#   '',
#   'Blue',
#   'Blond',
#   '',
#   ''],
#  ['White Canary',
#   '',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'F',
#   '',
#   'Brown',
#   'Black',
#   '10',
#   'good'],
#  ['Wyatt Wingfoot',
#   'Wyatt Wingfoot',
#   'Keewazi Reservation, Oklahoma',
#   'Marvel Comics',
#   '196.41999999999999',
#   '117.16',
#   'M',
#   '',
#   'Brown',
#   'Black',
#   '10',
#   'low'],
#  ['Weapon XI',
#   'Weapon XI',
#   '',
#   'Marvel Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Winter Soldier',
#   'Bucky Barnes',
#   '',
#   'Marvel Comics',
#   '175.21000000000001',
#   '117.20999999999999',
#   'M',
#   '2005',
#   'Brown',
#   'Brown',
#   '35',
#   'average'],
#  ['Watcher',
#   'Uatu',
#   '',
#   'Marvel Comics',
#   '',
#   '',
#   'M',
#   '1963',
#   '',
#   '',
#   '80',
#   'high'],
#  ['Wonder Man',
#   'Simon Williams',
#   'Paterson, New Jersey',
#   'Marvel Comics',
#   '188.90000000000001',
#   '171.56999999999999',
#   'M',
#   '',
#   'Red',
#   'Black',
#   '100',
#   'good'],
#  ['Wasp',
#   'Janet Van Dyne',
#   'Cresskill, New Jersey',
#   'Marvel Comics',
#   '163.86000000000001',
#   '50.039999999999999',
#   'F',
#   '',
#   'Blue',
#   'Auburn',
#   '20',
#   'good'],
#  ['Warlock',
#   'Adam Warlock',
#   'The Beehive, Shard Island, Atlantic Ocean',
#   'Marvel Comics',
#   '188.22',
#   '108.14',
#   'M',
#   '',
#   'Red',
#   'Blond',
#   '40',
#   'high'],
#  ['Warbird',
#   'Carol Danvers',
#   'Boston, Massachusetts',
#   'Marvel Comics',
#   '180.56',
#   '54.75',
#   'F',
#   '',
#   'Blue',
#   'Blond',
#   '',
#   ''],
#  ['Wildfire',
#   'Drake Burroughs',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '35',
#   'average'],
#  ['Vulture',
#   'Adrian Toomes',
#   'Staten Island, New York City ',
#   'Marvel Comics',
#   '180.61000000000001',
#   '79.629999999999995',
#   'M',
#   '',
#   'Brown',
#   'No Hair',
#   '25',
#   'good'],
#  ['Warp',
#   'Emil LaSalle',
#   '',
#   'DC Comics',
#   '173.41999999999999',
#   '67.420000000000002',
#   'M',
#   '1981',
#   'Brown',
#   'Black',
#   '10',
#   'moderate'],
#  ['Warpath',
#   'James Proudstar',
#   'Camp Verde, Arizona ',
#   'Marvel Comics',
#   '218.05000000000001',
#   '158.22',
#   'M',
#   '1984',
#   'Brown',
#   'Black',
#   '75',
#   'moderate'],
#  ['War Machine',
#   'James Rupert Rhodes',
#   'Philadelphia, Pennsylvania ',
#   'Marvel Comics',
#   '185.00999999999999',
#   '95.930000000000007',
#   'M',
#   '1979',
#   'Brown',
#   'Brown',
#   '80',
#   'good'],
#  ['Vulcan',
#   'Gabriel Summers',
#   '',
#   'Marvel Comics',
#   '',
#   '',
#   'M',
#   '',
#   'Black',
#   'Black',
#   '',
#   ''],
#  ['Vision II',
#   'Vision',
#   'Place of birth unknown',
#   'Marvel Comics',
#   '191.38999999999999',
#   '135.50999999999999',
#   '',
#   '',
#   'Red',
#   'No Hair',
#   '',
#   ''],
#  ['Walrus',
#   'Hubert Carpent',
#   'Brooklyn, New York',
#   'Marvel Comics',
#   '183.69999999999999',
#   '162.03',
#   'M',
#   '1984',
#   'Blue',
#   'Black',
#   '30',
#   'average'],
#  ['Vision',
#   'Vision',
#   '',
#   'Marvel Comics',
#   '191.50999999999999',
#   '135.94999999999999',
#   'M',
#   '',
#   'Gold',
#   'No Hair',
#   '75',
#   'high'],
#  ['Violet Parr',
#   'Violet Parr',
#   '',
#   'Dark Horse Comics',
#   '137.18000000000001',
#   '41.130000000000003',
#   'F',
#   '2004',
#   'Violet',
#   'Black',
#   '10',
#   'average'],
#  ['Violator',
#   '',
#   '',
#   'Image Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '65',
#   'average'],
#  ['Vertigo II',
#   '',
#   'The Savage Land',
#   'Marvel Comics',
#   '168.94',
#   '52.799999999999997',
#   'F',
#   '',
#   'Blue',
#   'Silver',
#   '',
#   ''],
#  ['Venompool',
#   'Wade Wilson',
#   '',
#   'Marvel Comics',
#   '226.84',
#   '',
#   'M',
#   '2011',
#   '',
#   '',
#   '60',
#   'good'],
#  ['Venom III',
#   'MacDonald Gargan',
#   '',
#   'Marvel Comics',
#   '229.38999999999999',
#   '334.69999999999999',
#   'M',
#   '2005',
#   'Brown',
#   'Brown',
#   '75',
#   'good'],
#  ['Vindicator',
#   'Dr. James McDonald Hudson',
#   '',
#   'Marvel Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Venom II',
#   'Angelo Fortunato',
#   '',
#   'Marvel Comics',
#   '175.06999999999999',
#   '50.759999999999998',
#   'M',
#   '2005',
#   'Brown',
#   'Black',
#   '60',
#   'average'],
#  ['Venom',
#   'Eddie Brock',
#   'New York, New York',
#   'Marvel Comics',
#   '191.34999999999999',
#   '117.61',
#   'M',
#   '',
#   'Blue',
#   'Strawberry Blond',
#   '60',
#   'good'],
#  ['Vegeta',
#   'Vegeta',
#   '',
#   'Shueisha',
#   '168.94',
#   '73.239999999999995',
#   'M',
#   '',
#   '',
#   'Black',
#   '100',
#   'high'],
#  ['Vixen',
#   'Mari McCabe',
#   'Zambesi',
#   'DC Comics',
#   '175.71000000000001',
#   '63.57',
#   'F',
#   '1981',
#   'Amber',
#   'Black',
#   '40',
#   'average'],
#  ['Valkyrie',
#   'Brunnhilde (also spelled Brunnhilda)',
#   'Presumably Asgard',
#   'Marvel Comics',
#   '191.63',
#   '214.66999999999999',
#   'F',
#   '',
#   'Blue',
#   'Blond',
#   '95',
#   'high'],
#  ['Valerie Hart',
#   '',
#   'East Coast, Canada',
#   'Team Epic TV',
#   '175.80000000000001',
#   '56.670000000000002',
#   'F',
#   '',
#   'Hazel',
#   'Black',
#   '',
#   ''],
#  ['Vanisher',
#   '',
#   'Boston, Massachusetts ',
#   'Marvel Comics',
#   '165.83000000000001',
#   '79.450000000000003',
#   'M',
#   '',
#   'Green',
#   'No Hair',
#   '10',
#   'good'],
#  ['Vagabond',
#   'Priscilla Lyons',
#   '',
#   'Marvel Comics',
#   '169.0',
#   '54.619999999999997',
#   'F',
#   '',
#   'Blue',
#   'Strawberry Blond',
#   '',
#   ''],
#  ['Utgard-Loki',
#   '',
#   'Jotunheim',
#   'Marvel Comics',
#   '15.34',
#   '58.859999999999999',
#   'M',
#   '',
#   'Blue',
#   'White',
#   '80',
#   'average'],
#  ['Ultron',
#   'Ultron',
#   'Created in Cresskill, New Jersey',
#   'Marvel Comics',
#   '206.90000000000001',
#   '331.61000000000001',
#   'M',
#   '1968',
#   'Red',
#   '',
#   '85',
#   'high'],
#  ['Triton',
#   'Triton',
#   'Island of Attilan, Atlantic Ocean',
#   'Marvel Comics',
#   '188.34999999999999',
#   '86.829999999999998',
#   'M',
#   '1965',
#   'Green',
#   'No Hair',
#   '65',
#   'average'],
#  ['Two-Face',
#   'Harvey Dent',
#   '',
#   'DC Comics',
#   '183.12',
#   '82.870000000000005',
#   'M',
#   '',
#   '',
#   '',
#   '10',
#   'high'],
#  ['Triplicate Girl',
#   'Luornu Durgo',
#   '',
#   'DC Comics',
#   '168.97',
#   '59.829999999999998',
#   'F',
#   '',
#   'Purple',
#   'Brown',
#   '10',
#   'good'],
#  ['Trigon',
#   '',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '1981',
#   'Yellow',
#   'Black',
#   '100',
#   'high'],
#  ['Ultragirl',
#   'Tsu-Zana',
#   '',
#   'Marvel Comics',
#   '168.27000000000001',
#   '105.90000000000001',
#   'F',
#   '',
#   'Blue',
#   'Blond',
#   '80',
#   'average'],
#  ['Tracy Strauss',
#   'Tracy Strauss',
#   'Beverly Hills, CA',
#   'NBC - Heroes',
#   '',
#   '',
#   'F',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Vindicator',
#   'Heather Hudson',
#   'Calgary, Alberta, Canada ',
#   'Marvel Comics',
#   '165.53999999999999',
#   '54.460000000000001',
#   'F',
#   '1980',
#   'Green',
#   'Red',
#   '65',
#   'good'],
#  ['Toxin',
#   'Eddie Brock',
#   'San Francisco, California',
#   'Marvel Comics',
#   '191.56999999999999',
#   '117.09',
#   'M',
#   '',
#   'Black',
#   'Blond',
#   '80',
#   'good'],
#  ['Titan', '', '', 'HarperCollins', '', '', 'M', '', '', '', '', ''],
#  ['Tinkerer',
#   'Phineas Mason',
#   '',
#   'Marvel Comics',
#   '163.96000000000001',
#   '54.93',
#   'M',
#   '1963',
#   'Brown',
#   'White',
#   '10',
#   'high'],
#  ['Tigra',
#   'Greer Grant Nelson',
#   'Presumably Chicago Illinois USA',
#   'Marvel Comics',
#   '178.03999999999999',
#   '81.120000000000005',
#   'F',
#   '',
#   'Green',
#   'Auburn',
#   '35',
#   'good'],
#  ['Vibe',
#   'Cisco Ramon',
#   '',
#   'DC Comics',
#   '178.77000000000001',
#   '71.319999999999993',
#   'M',
#   '',
#   'Brown',
#   'Black',
#   '10',
#   'average'],
#  ['Thundra',
#   'Thundra',
#   '',
#   'Marvel Comics',
#   '218.65000000000001',
#   '158.88999999999999',
#   'F',
#   '1972',
#   'Green',
#   'Red',
#   '85',
#   'moderate'],
#  ['Thunderstrike',
#   'Eric Kevin Masterson',
#   '',
#   'Marvel Comics',
#   '198.41999999999999',
#   '288.86000000000001',
#   'M',
#   '',
#   'Blue',
#   'Blond',
#   '80',
#   'good'],
#  ['Toxin',
#   'Patrick Mulligan',
#   'New York City ',
#   'Marvel Comics',
#   '188.69',
#   '97.560000000000002',
#   'M',
#   '2004',
#   'Blue',
#   'Brown',
#   '75',
#   'average'],
#  ['Thunderbird II',
#   'James Proudstar',
#   '',
#   'Marvel Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Thunderbird',
#   'John Proudstar',
#   'Camp Verde, Arizona ',
#   'Marvel Comics',
#   '185.12',
#   '101.48999999999999',
#   'M',
#   '1975',
#   'Brown',
#   'Black',
#   '35',
#   'average'],
#  ['Thor Girl',
#   'Tarene',
#   '',
#   'Marvel Comics',
#   '175.74000000000001',
#   '143.16999999999999',
#   'F',
#   '',
#   'Blue',
#   'Blond',
#   '85',
#   'good'],
#  ['Trickster',
#   'Giovanni Giuseppe',
#   '',
#   'DC Comics',
#   '183.53999999999999',
#   '81.370000000000005',
#   'M',
#   '1960',
#   'Blue',
#   'Blond',
#   '',
#   ''],
#  ['Thing',
#   'Ben Grimm',
#   'New York City, New York',
#   'Marvel Comics',
#   '183.55000000000001',
#   '225.41999999999999',
#   'M',
#   '1961',
#   'Blue',
#   'No Hair',
#   '85',
#   'good'],
#  ['The Comedian',
#   'Edward Morgen Blake',
#   '',
#   'DC Comics',
#   '188.41',
#   '101.45',
#   'M',
#   '1986',
#   'Brown',
#   'Black',
#   '15',
#   'good'],
#  ['The Cape',
#   'Vince Faraday',
#   '',
#   '',
#   '',
#   '',
#   'M',
#   '2011',
#   '',
#   '',
#   '10',
#   'moderate'],
#  ['Thanos',
#   'Thanos',
#   'Titan',
#   'Marvel Comics',
#   '201.25999999999999',
#   '443.19',
#   'M',
#   '',
#   'Red',
#   'No Hair',
#   '100',
#   'high'],
#  ['Tiger Shark',
#   'Todd Arliss',
#   'Pasadena, California',
#   'Marvel Comics',
#   '185.25',
#   '203.03',
#   'M',
#   '1968',
#   'Grey',
#   'No Hair',
#   '75',
#   'moderate'],
#  ['Thunderbird III',
#   'Neal Shaara',
#   'Bangladesh',
#   'Marvel Comics',
#   '175.86000000000001',
#   '74.280000000000001',
#   'M',
#   '',
#   'Brown',
#   'Black',
#   '',
#   ''],
#  ['Taskmaster',
#   'Tony Masters',
#   '',
#   'Marvel Comics',
#   '188.74000000000001',
#   '99.900000000000006',
#   'M',
#   '',
#   'Brown',
#   'Brown',
#   '15',
#   'good'],
#  ['Toad',
#   'Mortimer Toynbee',
#   'York, England ',
#   'Marvel Comics',
#   '175.31999999999999',
#   '76.040000000000006',
#   'M',
#   '1964',
#   'Black',
#   'Brown',
#   '35',
#   'average'],
#  ['T-X',
#   'Cyberdyne Systems Series X Terminator',
#   '',
#   'Dark Horse Comics',
#   '',
#   '149.33000000000001',
#   'F',
#   '',
#   '',
#   '',
#   '65',
#   'good'],
#  ['T-1000',
#   'Cyberdyne Systems Series 1000 Terminator',
#   '',
#   'Dark Horse Comics',
#   '183.33000000000001',
#   '146.83000000000001',
#   'M',
#   '',
#   '',
#   '',
#   '35',
#   'good'],
#  ['T-800',
#   'Cyberdyne Systems Series 800 Terminator Model 101',
#   '',
#   'Dark Horse Comics',
#   '',
#   '176.28',
#   'M',
#   '1984',
#   'Red',
#   '',
#   '35',
#   'good'],
#  ['T-850',
#   'Cyberdyne Systems Series 850 Terminator',
#   '',
#   'Dark Horse Comics',
#   '',
#   '198.72',
#   'M',
#   '2003',
#   'Red',
#   '',
#   '80',
#   'good'],
#  ['Synch',
#   'Everett Thomas',
#   '',
#   'Marvel Comics',
#   '180.68000000000001',
#   '74.0',
#   'M',
#   '1994',
#   'Brown',
#   'Black',
#   '70',
#   'good'],
#  ['Swarm',
#   'Fritz von Meyer',
#   '',
#   'Marvel Comics',
#   '196.71000000000001',
#   '47.109999999999999',
#   'M',
#   '1977',
#   'Yellow',
#   'No Hair',
#   '20',
#   'good'],
#  ['Thor',
#   'Thor Odinson',
#   'Asgard',
#   'Marvel Comics',
#   '198.34999999999999',
#   '288.61000000000001',
#   'M',
#   '1962',
#   'Blue',
#   'Blond',
#   '100',
#   'good'],
#  ['Swamp Thing',
#   'Alec Holland',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '1972',
#   'Red',
#   'No Hair',
#   '95',
#   'high'],
#  ['Supergirl',
#   'Kara Zor-El',
#   'Argo City, Krypton',
#   'DC Comics',
#   '165.40000000000001',
#   '54.799999999999997',
#   'F',
#   '2004',
#   'Blue',
#   'Blond',
#   '100',
#   'high'],
#  ['Superboy-Prime',
#   'Kal-El',
#   'Krypton (Earth-Prime) ',
#   'DC Comics',
#   '180.55000000000001',
#   '77.409999999999997',
#   'M',
#   '1985',
#   'Blue',
#   'Black / Blue',
#   '100',
#   'high'],
#  ['Sylar',
#   'Gabriel Gray',
#   '',
#   'NBC - Heroes',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '10',
#   'good'],
#  ['Tempest',
#   'Angel Salvadore Bohusk',
#   '',
#   'Marvel Comics',
#   '163.02000000000001',
#   '54.359999999999999',
#   'F',
#   '2001',
#   'Brown',
#   'Black',
#   '10',
#   'moderate'],
#  ['Stormtrooper',
#   '',
#   '',
#   'George Lucas',
#   '183.27000000000001',
#   '',
#   'M',
#   '1977',
#   '',
#   '',
#   '10',
#   'low'],
#  ['Sunspot',
#   'Roberto DaCosta',
#   'Rio de Janeiro, Brazil ',
#   'Marvel Comics',
#   '173.58000000000001',
#   '77.689999999999998',
#   'M',
#   '1982',
#   'brown',
#   'black',
#   '65',
#   'good'],
#  ['Storm',
#   'Ororo Munroe',
#   'New York, New York',
#   'Marvel Comics',
#   '180.72',
#   '57.5',
#   'F',
#   '1975',
#   'Blue',
#   'White',
#   '10',
#   'good'],
#  ['Stephanie Powell',
#   'Stephanie Powell',
#   '',
#   'ABC Studios',
#   '',
#   '',
#   'F',
#   '2010',
#   '',
#   'Blond',
#   '10',
#   'good'],
#  ['Superman',
#   'Clark Kent',
#   'Krypton',
#   'DC Comics',
#   '191.72999999999999',
#   '101.73',
#   'M',
#   '',
#   'Blue',
#   'Black',
#   '100',
#   'high'],
#  ['Stardust', '', '', 'Marvel Comics', '', '', 'M', '', '', '', '85', 'high'],
#  ['Steppenwolf',
#   '',
#   '',
#   'DC Comics',
#   '183.36000000000001',
#   '91.040000000000006',
#   'M',
#   '',
#   'Red',
#   'Black',
#   '100',
#   'high'],
#  ['Starfire',
#   "Koriand'r",
#   'Tamaran',
#   'DC Comics',
#   '193.77000000000001',
#   '71.780000000000001',
#   'F',
#   '1980',
#   'Green',
#   'Auburn',
#   '80',
#   'average'],
#  ['Superboy',
#   'Kon-El / Conner Kent',
#   'Project Cadmus cloning facility',
#   'DC Comics',
#   '170.61000000000001',
#   '68.909999999999997',
#   'M',
#   '1993',
#   'Blue',
#   'Black',
#   '95',
#   'good'],
#  ['Steel',
#   'John Irons',
#   'Washington, D.C.',
#   'DC Comics',
#   '201.58000000000001',
#   '131.13',
#   'M',
#   '1993',
#   'Brown',
#   'No Hair',
#   '85',
#   'high'],
#  ['Stargirl',
#   'Courtney Whitmore',
#   '',
#   'DC Comics',
#   '165.81',
#   '62.939999999999998',
#   'F',
#   '1999',
#   'Blue',
#   'Blond',
#   '80',
#   'good'],
#  ['Static',
#   'Virgil Hawkins',
#   'Paris Island, Dakota City',
#   'DC Comics',
#   '170.36000000000001',
#   '63.409999999999997',
#   'M',
#   '1993',
#   'Brown',
#   'Black',
#   '10',
#   'good'],
#  ['Star-Lord',
#   'Peter Jason Quill',
#   '',
#   'Marvel Comics',
#   '188.25',
#   '79.209999999999994',
#   'M',
#   '1976',
#   'Blue',
#   'Blond',
#   '20',
#   'good'],
#  ['Stacy X', '', '', 'Marvel Comics', '', '', 'F', '', '', '', '', ''],
#  ['Spock',
#   "S'chn T'gai Spock",
#   '',
#   'Star Trek',
#   '185.69',
#   '81.099999999999994',
#   'M',
#   '',
#   'Brown',
#   'Black',
#   '20',
#   'high'],
#  ['Spider-Woman III',
#   'Martha Franklin',
#   'Rochester, New York ',
#   'Marvel Comics',
#   '173.47',
#   '55.369999999999997',
#   'F',
#   '1998',
#   'Brown',
#   'Brown',
#   '50',
#   'average'],
#  ['Spyke',
#   'Evan Daniels',
#   '',
#   'Marvel Comics',
#   '183.00999999999999',
#   '83.370000000000005',
#   'M',
#   '2000',
#   'Brown',
#   'Blond',
#   '15',
#   'average'],
#  ['Spider-Man',
#   'Miles Morales',
#   '',
#   'Marvel Comics',
#   '157.37',
#   '56.060000000000002',
#   'M',
#   '2011',
#   'Brown',
#   'Black',
#   '',
#   ''],
#  ['Spider-Woman IV',
#   'Charlotte Witter',
#   '',
#   'Marvel Comics',
#   '178.09',
#   '58.780000000000001',
#   'F',
#   '',
#   'Red',
#   'White',
#   '',
#   ''],
#  ['Spider-Woman II', '', '', 'Marvel Comics', '', '', 'F', '', '', '', '', ''],
#  ['Spider-Woman',
#   'Jessica Drew',
#   'London, England',
#   'Marvel Comics',
#   '178.02000000000001',
#   '59.100000000000001',
#   'F',
#   '1977',
#   'Green',
#   'Black',
#   '45',
#   'average'],
#  ['Spider-Man',
#   "Miguel O'Hara",
#   '',
#   'Marvel Comics',
#   '178.66999999999999',
#   '77.269999999999996',
#   '',
#   '1992',
#   'Red',
#   'Brown',
#   '',
#   ''],
#  ['Spider-Man',
#   'Peter Parker',
#   'New York, New York',
#   'Marvel Comics',
#   '178.28',
#   '74.25',
#   'M',
#   '',
#   'Hazel',
#   'Brown',
#   '55',
#   'high'],
#  ['Spider-Girl',
#   "May 'Mayday' Parker",
#   'New York City, New York',
#   'Marvel Comics',
#   '170.97999999999999',
#   '54.75',
#   'F',
#   '1998',
#   'Blue',
#   'Brown',
#   '40',
#   'good'],
#  ['Spider-Gwen',
#   'Gwen Stacy',
#   '',
#   'Marvel Comics',
#   '165.78999999999999',
#   '56.590000000000003',
#   'F',
#   '',
#   'Blue',
#   'Blond',
#   '55',
#   'good'],
#  ['Speedball',
#   'Robert Baldwin',
#   'Springdale, Connecticut',
#   'Marvel Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Spider-Carnage',
#   'Benjamin Reilly',
#   '',
#   'Marvel Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Speedy',
#   'Thea Queen',
#   'Starling City',
#   'DC Comics',
#   '',
#   '',
#   'F',
#   '',
#   'Green',
#   'Brown',
#   '10',
#   'average'],
#  ['Speedy',
#   'Roy William Harper, Jr.',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Spawn',
#   'Al Simmons',
#   'Detroit, Michigan (8th level of Hell after rebirth)',
#   'Image Comics',
#   '211.5',
#   '405.58999999999997',
#   'M',
#   '1992',
#   'Brown',
#   'Black',
#   '60',
#   'good'],
#  ['Space Ghost',
#   'Thaddeus Bach',
#   '',
#   'DC Comics',
#   '188.86000000000001',
#   '113.78',
#   'M',
#   '1966',
#   '',
#   '',
#   '20',
#   'moderate'],
#  ['Spectre',
#   'Aztar',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '1940',
#   'White',
#   'No Hair',
#   '100',
#   'high'],
#  ['Songbird',
#   'Melissa Joan Gold',
#   'Shoshoni, Wyoming ',
#   'Marvel Comics',
#   '166.0',
#   '65.25',
#   'F',
#   '',
#   'Green',
#   'Red / White',
#   '40',
#   'good'],
#  ['Snowbird',
#   'Narya',
#   'Near Resolute Bay, Northwest Territories, Canada ',
#   'Marvel Comics',
#   '178.86000000000001',
#   '49.789999999999999',
#   'F',
#   '',
#   'White',
#   'Blond',
#   '35',
#   'average'],
#  ['Siryn',
#   'Theresa Rourke Cassidy',
#   'Cassidy Keep, County Mayo, Ireland ',
#   'Marvel Comics',
#   '168.84999999999999',
#   '52.640000000000001',
#   'F',
#   '',
#   'Blue',
#   'Strawberry Blond',
#   '10',
#   'moderate'],
#  ['Solomon Grundy',
#   'Cyrus Gold',
#   'Gotham City',
#   'DC Comics',
#   '279.22000000000003',
#   '437.61000000000001',
#   'M',
#   '1944',
#   'Black',
#   'White',
#   '95',
#   'low'],
#  ['Sobek',
#   'Yurrd the Unknown',
#   'Nile River; Bioengineered at Oolong Island',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '',
#   'White',
#   'No Hair',
#   '35',
#   'average'],
#  ['Snake-Eyes', '', '', 'Marvel Comics', '', '', 'M', '', '', '', '', ''],
#  ['Siren',
#   'Hila',
#   '',
#   'DC Comics',
#   '175.46000000000001',
#   '72.75',
#   'F',
#   '1965',
#   'Blue',
#   'Purple',
#   '65',
#   'average'],
#  ['Simon Baz',
#   'Simoon Baz',
#   'Dearborn, Michigan',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '2012',
#   'Bown',
#   'Black',
#   '90',
#   'average'],
#  ['Siren II',
#   'La Sirene la Bailene',
#   'Atlantis',
#   'DC Comics',
#   '',
#   '',
#   'F',
#   '1999',
#   'Black',
#   '',
#   '',
#   ''],
#  ['Silver Surfer',
#   'Norrin Radd',
#   'Zenn-La',
#   'Marvel Comics',
#   '193.00999999999999',
#   '101.34',
#   'M',
#   '',
#   'White',
#   'No Hair',
#   '100',
#   'average'],
#  ['Silk Spectre II',
#   'Laurie Juspeczyk',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'F',
#   '',
#   '',
#   '',
#   '55',
#   'high'],
#  ['Silk Spectre',
#   'Sally Juspeczyk',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'F',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Skaar',
#   '',
#   'Sakaar',
#   'Marvel Comics',
#   '198.46000000000001',
#   '180.69',
#   'M',
#   '',
#   'Green',
#   'Black',
#   '85',
#   'average'],
#  ['Silverclaw',
#   'Maria de Guadalupe Santiago',
#   'The village of Kamekeri, Costa Verde ',
#   'Marvel Comics',
#   '157.80000000000001',
#   '50.219999999999999',
#   'F',
#   '1998',
#   'Brown',
#   'Black',
#   '30',
#   'average'],
#  ['Shrinking Violet', '', '', 'DC Comics', '', '', 'F', '', '', '', '', ''],
#  ['Sif',
#   'Sif',
#   '',
#   'Marvel Comics',
#   '188.80000000000001',
#   '191.83000000000001',
#   'F',
#   '1964',
#   'Blue',
#   'Black',
#   '90',
#   'good'],
#  ['Shriek',
#   'Frances Louise Barrison',
#   '',
#   'Marvel Comics',
#   '173.94999999999999',
#   '52.829999999999998',
#   'F',
#   '',
#   'Yellow / Blue',
#   'Black',
#   '10',
#   'average'],
#  ['Sinestro',
#   'Thaal Sinestro',
#   'Korugar City, Korugar',
#   'DC Comics',
#   '201.13999999999999',
#   '92.640000000000001',
#   'M',
#   '',
#   'Black',
#   'Black',
#   '85',
#   'good'],
#  ['Shazam',
#   'Billy Batson',
#   'Fawcett City, United States',
#   'DC Comics',
#   '193.74000000000001',
#   '101.3',
#   'M',
#   '1940',
#   'Blue',
#   'Black',
#   '100',
#   'high'],
#  ['Shatterstar',
#   'Gaveedra Seven',
#   'Mojoworld',
#   'Marvel Comics',
#   '191.56999999999999',
#   '88.930000000000007',
#   'M',
#   '',
#   'Brown',
#   'Red',
#   '50',
#   'good'],
#  ['She-Thing',
#   'Sharon Ventura',
#   '',
#   'Marvel Comics',
#   '183.88999999999999',
#   '153.41',
#   'F',
#   '',
#   'Blue',
#   'No Hair',
#   '75',
#   'good'],
#  ['Shadowcat',
#   'Kitty Pryde',
#   'Deerfield, Illinois',
#   'Marvel Comics',
#   '168.63',
#   '50.399999999999999',
#   'F',
#   '1980',
#   'Hazel',
#   'Brown',
#   '10',
#   'high'],
#  ['Shang-Chi',
#   'Shang-Chi',
#   '',
#   'Marvel Comics',
#   '178.38',
#   '79.290000000000006',
#   'M',
#   '1973',
#   'Brown',
#   'Black',
#   '15',
#   'good'],
#  ['Shadow King',
#   'Amahl Farouk',
#   '',
#   'Marvel Comics',
#   '185.47999999999999',
#   '149.19',
#   '',
#   '1979',
#   'Red',
#   '',
#   '15',
#   'good'],
#  ['Shadow Lass',
#   'Tasmia Mallor',
#   'Talok VIII',
#   'DC Comics',
#   '173.11000000000001',
#   '54.25',
#   'F',
#   '',
#   'Black',
#   'Black',
#   '10',
#   'good'],
#  ['Sebastian Shaw',
#   'Sebastian Hiram Shaw',
#   '',
#   'Marvel Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '85',
#   'good'],
#  ['Silk',
#   'Cindy Moon',
#   '',
#   'Marvel Comics',
#   '',
#   '',
#   'F',
#   '',
#   'Brown',
#   'Black',
#   '50',
#   'good'],
#  ['Shocker',
#   'Herman Schultz',
#   '',
#   'Marvel Comics',
#   '175.62',
#   '79.400000000000006',
#   'M',
#   '',
#   'Brown',
#   'Brown',
#   '10',
#   'good'],
#  ['Scorpia',
#   'Elaine Coll',
#   '',
#   'Marvel Comics',
#   '',
#   '',
#   'F',
#   '1995',
#   'Green',
#   'Red',
#   '30',
#   'moderate'],
#  ['Scorpion',
#   'MacDonald Gargan',
#   '',
#   'Marvel Comics',
#   '211.06',
#   '310.20999999999998',
#   'M',
#   '1964',
#   'Brown',
#   'Brown',
#   '55',
#   'average'],
#  ['Scarlet Witch',
#   'Wanda Maximoff',
#   'Wundagore Mountain, Transia',
#   'Marvel Comics',
#   '170.18000000000001',
#   '59.689999999999998',
#   'F',
#   '1964',
#   'Blue',
#   'Brown',
#   '10',
#   'high'],
#  ['Scarlet Spider II',
#   'Kaine Parker',
#   '',
#   'Marvel Comics',
#   '193.21000000000001',
#   '113.66',
#   'M',
#   '1994',
#   'Brown',
#   'Brown',
#   '55',
#   'high'],
#  ['Scarlet Spider',
#   'Benjamin Reilly',
#   'Place of birth unknown',
#   'Marvel Comics',
#   '178.78999999999999',
#   '74.969999999999999',
#   'M',
#   '',
#   'Blue',
#   'Blond',
#   '55',
#   'good'],
#  ['Sentry',
#   'Robert Reynolds',
#   '',
#   'Marvel Comics',
#   '188.84',
#   '87.950000000000003',
#   'M',
#   '2000',
#   'Blue',
#   'Blond',
#   '100',
#   'good'],
#  ['Savage Dragon',
#   'Kurr',
#   '',
#   'Image Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '70',
#   'good'],
#  ['Sandman',
#   'William Baker',
#   'Queens, New York',
#   'Marvel Comics',
#   '185.37',
#   '203.28999999999999',
#   'M',
#   '1963',
#   'Brown',
#   'Brown',
#   '75',
#   'average'],
#  ['Sasquatch',
#   'Walter Langkowski',
#   'Edmonton, Alberta, Canada ',
#   'Marvel Comics',
#   '305.01999999999998',
#   '900.70000000000005',
#   'M',
#   '',
#   'Red',
#   'Orange',
#   '80',
#   'good'],
#  ['Sage',
#   'Tessa',
#   'Place of birth unknown',
#   'Marvel Comics',
#   '170.27000000000001',
#   '61.509999999999998',
#   'F',
#   '',
#   'Blue',
#   'Black',
#   '10',
#   'good'],
#  ['Scarecrow',
#   'Jonathan Crane',
#   '',
#   'DC Comics',
#   '183.09',
#   '63.950000000000003',
#   'M',
#   '1941',
#   'Blue',
#   'Brown',
#   '10',
#   'high'],
#  ['Sabretooth',
#   'Victor Creed',
#   '',
#   'Marvel Comics',
#   '198.44',
#   '171.74000000000001',
#   'M',
#   '1977',
#   'Amber',
#   'Blond',
#   '50',
#   'average'],
#  ['Ronin',
#   'Clint Barton',
#   'Waverly, Iowa ',
#   'Marvel Comics',
#   '191.05000000000001',
#   '104.16',
#   'M',
#   '',
#   'Blue',
#   'Blond',
#   '15',
#   'average'],
#  ['Rorschach',
#   'Walter Joseph Kovacs',
#   '',
#   'DC Comics',
#   '168.59999999999999',
#   '63.060000000000002',
#   'M',
#   '1986',
#   'Blue',
#   'Red',
#   '10',
#   'good'],
#  ['Rocket Raccoon',
#   'Rocket Raccoon',
#   '',
#   'Marvel Comics',
#   '122.77',
#   '25.73',
#   'M',
#   '1976',
#   'Brown',
#   'Brown',
#   '5',
#   'average'],
#  ['Rogue',
#   'Anna Marie',
#   'Caldecott County, Mississippi ',
#   'Marvel Comics',
#   '173.47999999999999',
#   '54.43',
#   'F',
#   '1981',
#   'Green',
#   'Brown / White',
#   '10',
#   'good'],
#  ['Robin VI',
#   'Carrie Kelley',
#   'Gotham City',
#   'DC Comics',
#   '',
#   '',
#   'F',
#   '',
#   'Green',
#   'Red',
#   '10',
#   'average'],
#  ['Robin V',
#   'Damian Wayne',
#   '',
#   'DC Comics',
#   '137.24000000000001',
#   '38.460000000000001',
#   'M',
#   '',
#   'Blue',
#   'Black',
#   '10',
#   'good'],
#  ['She-Hulk',
#   'Jennifer Walters',
#   'Los Angeles, California',
#   'Marvel Comics',
#   '201.68000000000001',
#   '315.25999999999999',
#   'F',
#   '',
#   'Green',
#   'Green',
#   '100',
#   'high'],
#  ['Ripcord',
#   'Miranda Leevald',
#   '',
#   'Marvel Comics',
#   '180.86000000000001',
#   '72.569999999999993',
#   'F',
#   '',
#   'Green',
#   'Black',
#   '',
#   ''],
#  ['Robin III',
#   'Tim Drake',
#   '',
#   'DC Comics',
#   '165.94',
#   '56.030000000000001',
#   'M',
#   '1989',
#   'Blue',
#   'Black',
#   '15',
#   'high'],
#  ['Robin II',
#   'Jason Todd',
#   '',
#   'DC Comics',
#   '183.41',
#   '101.63',
#   'M',
#   '',
#   'Blue',
#   'Red',
#   '15',
#   'good'],
#  ['Rick Flag',
#   'Richard Rogers Flag',
#   '',
#   'DC Comics',
#   '185.78',
#   '85.909999999999997',
#   'M',
#   '1959',
#   'Blue',
#   'Brown',
#   '15',
#   'high'],
#  ['Rip Hunter',
#   'Richard Hunter',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '',
#   'Blue',
#   'Blond',
#   '10',
#   'high'],
#  ['Rhino',
#   'Aleksei Mikhailovich Sytsevich',
#   '',
#   'Marvel Comics',
#   '196.94',
#   '320.95999999999998',
#   'M',
#   '',
#   'Brown',
#   'Brown',
#   '80',
#   'moderate'],
#  ['Riddler',
#   'Edward Nigma',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '1948',
#   '',
#   '',
#   '10',
#   'high'],
#  ['Redeemer III',
#   'Eddie Frank',
#   '',
#   'Image Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Redeemer II',
#   'Phil Timper',
#   '',
#   'Image Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Red Tornado',
#   'John Smith',
#   '',
#   'DC Comics',
#   '185.94999999999999',
#   '146.22',
#   'M',
#   '',
#   'Green',
#   'No Hair',
#   '40',
#   'good'],
#  ['Rey',
#   '',
#   'Jakku',
#   'George Lucas',
#   '297.12',
#   '',
#   'F',
#   '2015',
#   'Hazel',
#   'Brown',
#   '10',
#   'good'],
#  ['Robin',
#   'Dick Grayson',
#   '',
#   'DC Comics',
#   '178.21000000000001',
#   '79.489999999999995',
#   'M',
#   '1940',
#   'Blue',
#   'Black',
#   '15',
#   'high'],
#  ['Red Robin',
#   'Tim Drake',
#   'Gotham City',
#   'DC Comics',
#   '165.38999999999999',
#   '56.350000000000001',
#   'M',
#   '1989',
#   'Blue',
#   'Black',
#   '15',
#   'high'],
#  ['Renata Soliz', '', '', 'HarperCollins', '', '', 'F', '', '', '', '', ''],
#  ['Sauron',
#   'Sauron',
#   '',
#   'J. R. R. Tolkien',
#   '279.89999999999998',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '85',
#   'high'],
#  ['Red Hood',
#   'Jason Todd',
#   '',
#   'DC Comics',
#   '183.80000000000001',
#   '81.150000000000006',
#   'M',
#   '',
#   'Blue',
#   'Black',
#   '15',
#   'good'],
#  ['Red Hulk',
#   'Thaddeus E. Ross',
#   '',
#   'Marvel Comics',
#   '213.97999999999999',
#   '630.09000000000003',
#   'M',
#   '2008',
#   'Yellow',
#   'Black',
#   '100',
#   'average'],
#  ['Red Mist',
#   'Chris Genovese',
#   '',
#   'Icon Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '10',
#   'moderate'],
#  ['Red Arrow',
#   'Roy Harper',
#   '',
#   'DC Comics',
#   '180.49000000000001',
#   '83.579999999999998',
#   'M',
#   '2007',
#   'Green',
#   'Red',
#   '20',
#   'good'],
#  ['Ray',
#   'Ray Terrill',
#   '',
#   'DC Comics',
#   '178.38999999999999',
#   '70.959999999999994',
#   'M',
#   '',
#   'Green',
#   'Red',
#   '10',
#   'average'],
#  ['Raven',
#   'Rachel Roth',
#   'Azarath',
#   'DC Comics',
#   '165.00999999999999',
#   '50.409999999999997',
#   'F',
#   '1980',
#   'Indigo',
#   'Black',
#   '10',
#   'average'],
#  ['Rambo',
#   'John Rambo',
#   'Bowie, Arizona',
#   '',
#   '178.94999999999999',
#   '83.730000000000004',
#   'M',
#   '1972',
#   'Brown',
#   'Black',
#   '15',
#   'good'],
#  ['Razor-Fist II',
#   'Douglas Scott',
#   '',
#   'Marvel Comics',
#   '191.11000000000001',
#   '117.56999999999999',
#   'M',
#   '1981',
#   'Blue',
#   'No Hair',
#   '',
#   ''],
#  ['Rachel Pirzad', '', '', 'SyFy', '', '', 'F', '', '', '', '5', 'good'],
#  ['Red Skull',
#   'Johann Shmidt',
#   'An unidentified village in Germany',
#   'Marvel Comics',
#   '188.31999999999999',
#   '108.08',
#   'M',
#   '1965',
#   'Blue',
#   'No Hair',
#   '10',
#   'good'],
#  ['Quill',
#   'Maxwell Jordan',
#   '',
#   'Marvel Comics',
#   '163.63',
#   '56.109999999999999',
#   'M',
#   '',
#   'Brown',
#   'Brown',
#   '10',
#   'moderate'],
#  ['Quantum', '', '', 'HarperCollins', '', '', 'M', '', '', '', '', ''],
#  ['Quicksilver',
#   'Pietro Django Maximoff',
#   'Wundagore Mountain, Transia (in Eastern Europe)',
#   'Marvel Comics',
#   '183.47999999999999',
#   '79.359999999999999',
#   'M',
#   '',
#   'Blue',
#   'Silver',
#   '30',
#   'good'],
#  ['Pyro',
#   'St. John Allerdyce',
#   'Sydney, Australia ',
#   'Marvel Comics',
#   '178.72',
#   '68.480000000000004',
#   'M',
#   '',
#   'Blue',
#   'Blond',
#   '10',
#   'moderate'],
#  ['Q', 'Q', '', 'Star Trek', '', '', 'M', '', '', '', '15', 'high'],
#  ['Question',
#   'Charles Victor Szasz',
#   '',
#   'DC Comics',
#   '188.41',
#   '83.260000000000005',
#   'M',
#   '1967',
#   'Blue',
#   'Blond',
#   '15',
#   'high'],
#  ['Punisher',
#   'Frank Castle',
#   'Queens, New York',
#   'Marvel Comics',
#   '183.25999999999999',
#   '90.900000000000006',
#   'M',
#   '',
#   'Blue',
#   'Black',
#   '20',
#   'good'],
#  ["Ra's Al Ghul",
#   "Ra's Al Ghul",
#   'Egypt',
#   'DC Comics',
#   '193.06',
#   '97.760000000000005',
#   'M',
#   '1971',
#   'Green',
#   'Grey',
#   '30',
#   'high'],
#  ['Purple Man',
#   'Zebediah Killgrave',
#   '',
#   'Marvel Comics',
#   '180.30000000000001',
#   '74.129999999999995',
#   'M',
#   '1964',
#   'Purple',
#   'Purple',
#   '10',
#   'average'],
#  ['Psylocke',
#   'Elizabeth Braddock',
#   'Braddock Manor, England',
#   'Marvel Comics',
#   '180.88',
#   '70.959999999999994',
#   'F',
#   '1986',
#   'Blue',
#   'Purple',
#   '35',
#   'good'],
#  ['Professor X',
#   'Charles Francis Xavier',
#   'New York, New York',
#   'Marvel Comics',
#   '183.74000000000001',
#   '86.890000000000001',
#   'M',
#   '1963',
#   'Blue',
#   'No Hair',
#   '10',
#   'high'],
#  ['Proto-Goblin',
#   'Nels Van Adder',
#   '',
#   'Marvel Comics',
#   '',
#   '',
#   'M',
#   '1990',
#   'Green',
#   'Blond',
#   '40',
#   'good'],
#  ['Predator',
#   'Yautja',
#   'Yautja Prime',
#   'Dark Horse Comics',
#   '213.59',
#   '234.19',
#   'M',
#   '1987',
#   '',
#   '',
#   '30',
#   'good'],
#  ['Power Man',
#   'Luke Cage',
#   '',
#   'Marvel Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Polaris',
#   'Lorna Dane',
#   'Presumably northern California - not confirmed',
#   'Marvel Comics',
#   '170.90000000000001',
#   '52.890000000000001',
#   'F',
#   '1968',
#   'Green',
#   'Green',
#   '75',
#   'good'],
#  ['Poison Ivy',
#   'Pamela Isley',
#   'Seattle, Washington',
#   'DC Comics',
#   '168.13999999999999',
#   '50.939999999999998',
#   'F',
#   '',
#   'Green',
#   'Red',
#   '15',
#   'high'],
#  ['Power Girl',
#   'Kara Zor-L',
#   '',
#   'DC Comics',
#   '180.59',
#   '81.640000000000001',
#   'F',
#   '1976',
#   'blue',
#   'blond',
#   '100',
#   'high'],
#  ['Plastique',
#   'Bette Sans Souci',
#   '',
#   'DC Comics',
#   '168.96000000000001',
#   '55.759999999999998',
#   'F',
#   '',
#   'Blue',
#   'Red',
#   '10',
#   'average'],
#  ['Plastic Man',
#   "Patrick O'Brian",
#   '',
#   'DC Comics',
#   '185.71000000000001',
#   '80.280000000000001',
#   'M',
#   '1941',
#   'Blue',
#   'Black',
#   '65',
#   'average'],
#  ['Professor Zoom',
#   'Eobard Thawne',
#   '',
#   'DC Comics',
#   '180.78999999999999',
#   '81.799999999999997',
#   'M',
#   '1963',
#   'Blue',
#   'Strawberry Blond',
#   '10',
#   'high'],
#  ['Plantman',
#   'Samuel Smithers',
#   'London, England',
#   'Marvel Comics',
#   '183.53999999999999',
#   '87.620000000000005',
#   'M',
#   '1963',
#   'Green',
#   'Grey',
#   '60',
#   'good'],
#  ['Phantom Stranger',
#   'Judas Iscariot',
#   '',
#   'DC Comics',
#   '188.22',
#   '83.840000000000003',
#   'M',
#   '',
#   'Black',
#   'Black',
#   '10',
#   'high'],
#  ['Raphael',
#   '',
#   '',
#   'IDW Publishing',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   'No Hair',
#   '20',
#   'good'],
#  ['Phantom Girl',
#   'Tinya Wazzo',
#   '',
#   'DC Comics',
#   '168.58000000000001',
#   '54.990000000000002',
#   'F',
#   '2004',
#   'Blue',
#   'Black',
#   '10',
#   'moderate'],
#  ['Peter Petrelli',
#   'Peter Petrelli',
#   '',
#   'NBC - Heroes',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '30',
#   'good'],
#  ['Phantom',
#   'Christopher Walker',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '50',
#   'good'],
#  ['Phoenix',
#   'Jean Grey',
#   '',
#   'Marvel Comics',
#   '168.88999999999999',
#   '52.07',
#   'F',
#   '1963',
#   'Green',
#   'Red',
#   '100',
#   'high'],
#  ['Penguin',
#   'Oswald Chesterfield Cobblepot',
#   '',
#   'DC Comics',
#   '157.88999999999999',
#   '79.129999999999995',
#   'M',
#   '1941',
#   'Blue',
#   'Black',
#   '10',
#   'good'],
#  ['Penance II',
#   'Robert Baldwin',
#   'Springdale, Connecticut ',
#   'Marvel Comics',
#   '183.72',
#   '89.900000000000006',
#   'M',
#   '2007',
#   'Blue',
#   'Blond',
#   '20',
#   'average'],
#  ['Plastic Lad',
#   "Luke O'Brian",
#   '',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Penance', '', '', 'Marvel Comics', '', '', '', '', '', '', '', ''],
#  ['Penance I', '', '', 'Marvel Comics', '', '', 'F', '', '', '', '', ''],
#  ['Paul Blart',
#   'Paul Blart',
#   '',
#   'Sony Pictures',
#   '170.43000000000001',
#   '117.59999999999999',
#   'M',
#   '',
#   '',
#   '',
#   '15',
#   'low'],
#  ['Parademon',
#   '',
#   'Apokalips',
#   'DC Comics',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '30',
#   'low'],
#  ['Ozymandias',
#   'Adrian Veidt',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '',
#   'Blue',
#   'Blond',
#   '20',
#   'high'],
#  ['Overtkill',
#   'Nicholas Rocca',
#   '',
#   'Image Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Osiris',
#   'Amon Tomaz',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '',
#   'Brown',
#   'Brown',
#   '85',
#   'good'],
#  ['Oracle',
#   'Barbara Gordon',
#   '',
#   'DC Comics',
#   '178.12',
#   '59.329999999999998',
#   'F',
#   '1989',
#   'Blue',
#   'Red',
#   '15',
#   'good'],
#  ['Onslaught',
#   'Onslaught',
#   '',
#   'Marvel Comics',
#   '305.41000000000003',
#   '405.07999999999998',
#   'M',
#   '1996',
#   'Red',
#   'No Hair',
#   '100',
#   'high'],
#  ['One-Above-All',
#   '',
#   '',
#   'Marvel Comics',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '100',
#   'high'],
#  ['One Punch Man',
#   'Saitama',
#   '',
#   'Shueisha',
#   '175.63999999999999',
#   '69.950000000000003',
#   'M',
#   '',
#   '',
#   'No Hair',
#   '100',
#   'moderate'],
#  ['Omega Red',
#   'Arkady Gregorivich',
#   '',
#   'Marvel Comics',
#   '211.78999999999999',
#   '191.40000000000001',
#   'M',
#   '',
#   'Red',
#   'Blond',
#   '',
#   ''],
#  ['Omniscient',
#   'Omniscient is the closest English word that compares to his alien tongue.',
#   'Another Unknown World',
#   'Team Epic TV',
#   '180.22',
#   '65.299999999999997',
#   'M',
#   '',
#   'Brown',
#   'Black',
#   '',
#   ''],
#  ['Odin',
#   'Odin Borson',
#   'Asgard',
#   'Marvel Comics',
#   '206.15000000000001',
#   '293.35000000000002',
#   'M',
#   '',
#   'Blue',
#   'White',
#   '85',
#   'high'],
#  ['Nova',
#   'Richard Rider',
#   'Queens, NY',
#   'Marvel Comics',
#   '185.25',
#   '86.370000000000005',
#   'M',
#   '1976',
#   'Brown',
#   'Brown',
#   '85',
#   'high'],
#  ['Nova',
#   'Frankie Raye',
#   '',
#   'Marvel Comics',
#   '163.93000000000001',
#   '59.719999999999999',
#   'F',
#   '1975',
#   'White',
#   'Red',
#   '60',
#   'good'],
#  ['Offspring',
#   "Luke O'Brian",
#   '',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '10',
#   'average'],
#  ['Nite Owl II',
#   'Daniel Dreiberg',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Northstar',
#   'Jean-Paul Beaubier',
#   'Montreal, Qu�bec, Canada ',
#   'Marvel Comics',
#   '180.66',
#   '83.019999999999996',
#   'M',
#   '1979',
#   'Blue',
#   'Black',
#   '20',
#   'average'],
#  ['Niki Sanders',
#   'Nicole Sanders',
#   '',
#   'NBC - Heroes',
#   '',
#   '',
#   'F',
#   '',
#   'Blue',
#   'Blond',
#   '55',
#   'good'],
#  ['Nick Fury',
#   'Nicholas Joseph Fury',
#   'New York City',
#   'Marvel Comics',
#   '185.88',
#   '99.280000000000001',
#   'M',
#   '1963',
#   'Brown',
#   'Brown / White',
#   '15',
#   'good'],
#  ['Nightwing',
#   'Dick Grayson',
#   'Gotham City',
#   'DC Comics',
#   '178.31',
#   '79.069999999999993',
#   'M',
#   '',
#   'Blue',
#   'Black',
#   '15',
#   'high'],
#  ['Nightcrawler',
#   'Kurt Wagner',
#   'Somewhere in the Bavarian Alps',
#   'Marvel Comics',
#   '175.30000000000001',
#   '88.140000000000001',
#   'M',
#   '',
#   'Yellow',
#   'Indigo',
#   '10',
#   'average'],
#  ['Nebula',
#   '',
#   '',
#   'Marvel Comics',
#   '185.08000000000001',
#   '83.189999999999998',
#   'F',
#   '1985',
#   'Blue',
#   'No Hair',
#   '55',
#   'good'],
#  ['Negasonic Teenage Warhead',
#   'Ellie Phimister',
#   '',
#   'Marvel Comics',
#   '',
#   '',
#   'F',
#   '',
#   'Black',
#   'Black',
#   '10',
#   'average'],
#  ['Nina Theroux', '', '', 'SyFy', '', '', 'F', '', '', '', '5', 'good'],
#  ['Nathan Petrelli',
#   'Nathan Petrelli',
#   '',
#   'NBC - Heroes',
#   '',
#   '',
#   'M',
#   '',
#   'Brown',
#   '',
#   '',
#   ''],
#  ['Naruto Uzumaki',
#   '',
#   '',
#   'Shueisha',
#   '168.13999999999999',
#   '54.130000000000003',
#   'M',
#   '',
#   '',
#   '',
#   '80',
#   'average'],
#  ['Namorita',
#   'Namorita Prentiss',
#   'Atlantis Outskirts',
#   'Marvel Comics',
#   '168.78999999999999',
#   '101.41',
#   'F',
#   '1972',
#   'Blue',
#   'Blond',
#   '75',
#   'average'],
#  ['Namor',
#   'Namor McKenzie',
#   'Atlantis',
#   'Marvel Comics',
#   '188.38999999999999',
#   '125.23999999999999',
#   'M',
#   '1939',
#   'Grey',
#   'Black',
#   '95',
#   'good'],
#  ['Namor', '', '', 'Marvel Comics', '', '', 'M', '', '', '', '', ''],
#  ['Mystique',
#   'Raven Darkholme',
#   '',
#   'Marvel Comics',
#   '178.65000000000001',
#   '54.960000000000001',
#   'F',
#   '',
#   'Yellow (without irises)',
#   'Red / Orange',
#   '15',
#   'good'],
#  ['Namora',
#   'Aquaria Nautica Neptunia',
#   'Unnamed Atlantean outpost',
#   'Marvel Comics',
#   '180.84999999999999',
#   '85.530000000000001',
#   'F',
#   '1947',
#   'Blue',
#   'Blond',
#   '85',
#   'average'],
#  ['Mysterio',
#   'Quentin Beck',
#   'New York, New York ',
#   'Marvel Comics',
#   '180.47',
#   '79.930000000000007',
#   'M',
#   '1964',
#   'Brown',
#   'No Hair',
#   '10',
#   'high'],
#  ['Multiple Man',
#   'James Arthur',
#   'Los Alamos, New Mexico',
#   'Marvel Comics',
#   '180.91999999999999',
#   '70.180000000000007',
#   'M',
#   '',
#   'Blue',
#   'Brown',
#   '15',
#   'good'],
#  ['Ms Marvel II',
#   'Sharon Ventura',
#   'Pullman, Washington',
#   'Marvel Comics',
#   '173.44999999999999',
#   '61.609999999999999',
#   'F',
#   '',
#   'Blue',
#   'Red',
#   '65',
#   'moderate'],
#  ['Mr Incredible',
#   'Robert Parr',
#   '',
#   'Dark Horse Comics',
#   '201.81',
#   '158.19999999999999',
#   'M',
#   '2004',
#   'Blue',
#   'Blond',
#   '85',
#   'average'],
#  ['Mr Immortal',
#   'Craig Hollis',
#   '',
#   'Marvel Comics',
#   '188.81',
#   '70.090000000000003',
#   'M',
#   '',
#   'Blue',
#   'Blond',
#   '10',
#   'average'],
#  ['Morph',
#   'Kevin Sydney',
#   'Pittsburgh, Pennsylvania ',
#   'Marvel Comics',
#   '178.31',
#   '79.879999999999995',
#   'M',
#   '',
#   'White',
#   'No Hair',
#   '',
#   ''],
#  ['Moonstone',
#   'Karla Sofen',
#   'Van Nuys, California',
#   'Marvel Comics',
#   '180.72',
#   '59.780000000000001',
#   'F',
#   '1975',
#   'Blue',
#   'Blond',
#   '70',
#   'average'],
#  ['Moses Magnum',
#   'Moses Magnum',
#   '',
#   'Marvel Comics',
#   '175.06',
#   '72.870000000000005',
#   'M',
#   '1975',
#   'Brown',
#   'Black',
#   '30',
#   'good'],
#  ['Morlun',
#   'Morlun',
#   '',
#   'Marvel Comics',
#   '188.25999999999999',
#   '79.519999999999996',
#   'M',
#   '2001',
#   'White / Red',
#   'Black',
#   '60',
#   'good'],
#  ['Moon Knight',
#   'Marc Spector ',
#   'Chicago, Illinois',
#   'Marvel Comics',
#   '188.71000000000001',
#   '101.34999999999999',
#   'M',
#   '1975',
#   'Brown',
#   'Brown',
#   '40',
#   'average'],
#  ['Monica Dawson',
#   'Monica Dawson',
#   '',
#   'NBC - Heroes',
#   '',
#   '',
#   'F',
#   '',
#   '',
#   '',
#   '10',
#   'average'],
#  ['Molten Man',
#   'Mark Raxton',
#   '',
#   'Marvel Comics',
#   '196.96000000000001',
#   '248.27000000000001',
#   'M',
#   '1965',
#   'Gold',
#   'Gold',
#   '75',
#   'average'],
#  ['Monarch',
#   'Nathaniel Christopher Adam',
#   '',
#   'DC Comics',
#   '193.56999999999999',
#   '90.719999999999999',
#   'M',
#   '1987',
#   'Blue',
#   'White',
#   '100',
#   'high'],
#  ['Mogo', 'Mogo', '', 'DC Comics', '', '', 'M', '1985', '', '', '', ''],
#  ['MODOK',
#   'George Tarleton',
#   '',
#   'Marvel Comics',
#   '366.19999999999999',
#   '338.20999999999998',
#   'M',
#   '',
#   'White',
#   'Brownn',
#   '20',
#   'high'],
#  ['Mohinder Suresh',
#   'Mohinder Suresh',
#   'India',
#   'NBC - Heroes',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Mockingbird',
#   'Barbara Morse',
#   'San Diego, California',
#   'Marvel Comics',
#   '175.58000000000001',
#   '61.329999999999998',
#   'F',
#   '1971',
#   'Blue',
#   'Blond',
#   '35',
#   'good'],
#  ['Moloch',
#   'Edgar William Jacobi',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Mister Zsasz',
#   'Victor Zsasz',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '',
#   'Blue',
#   'Blond',
#   '25',
#   'high'],
#  ['Mister Sinister',
#   'Nathaniel Essex',
#   'London, England ',
#   'Marvel Comics',
#   '196.88999999999999',
#   '128.37',
#   'M',
#   '1987',
#   'Red',
#   'Black',
#   '50',
#   'high'],
#  ['Mister Mxyzptlk',
#   'Mr. Mxyzptlk',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '85',
#   'high'],
#  ['Mister Freeze',
#   'Victor Fries',
#   '',
#   'DC Comics',
#   '183.59',
#   '86.469999999999999',
#   'M',
#   '1959',
#   '',
#   '',
#   '35',
#   'good'],
#  ['Mister Fantastic',
#   'Reed Richards',
#   'Central City, California ',
#   'Marvel Comics',
#   '185.00999999999999',
#   '81.680000000000007',
#   'M',
#   '',
#   'Brown',
#   'Brown',
#   '10',
#   'high'],
#  ['Mister Knife',
#   "J'son",
#   "Spartax, Spartoi Empire, near the Shi'ar Galaxy",
#   'Marvel Comics',
#   '',
#   '',
#   'M',
#   '2000',
#   'Blue',
#   'Brown',
#   '10',
#   'good'],
#  ['Misfit',
#   'Charlotte Gage-Radcliffe',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'F',
#   '',
#   'Blue',
#   'Red',
#   '35',
#   'good'],
#  ['Mimic',
#   'Calvin Montgomery Rankin',
#   'Passiac, New Jersey ',
#   'Marvel Comics',
#   '188.78999999999999',
#   '101.48',
#   'M',
#   '',
#   'Brown',
#   'Brown',
#   '70',
#   'good'],
#  ['Miss Martian',
#   "M'gann M'orzz",
#   'Mars',
#   'DC Comics',
#   '178.49000000000001',
#   '61.25',
#   'F',
#   '2006',
#   'Red',
#   'Red',
#   '85',
#   'good'],
#  ['Minna Murray',
#   'Wilhelmina Harker',
#   '',
#   'Wildstorm',
#   '',
#   '',
#   'F',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Micro Lad',
#   'Gim Allon',
#   '',
#   'DC Comics',
#   '183.12',
#   '77.219999999999999',
#   'M',
#   '2004',
#   'Grey',
#   'Brown',
#   '30',
#   'moderate'],
#  ['Micah Sanders',
#   'Micah Sanders',
#   '',
#   'NBC - Heroes',
#   '',
#   '',
#   'M',
#   '',
#   'Brown',
#   'Black',
#   '10',
#   'good'],
#  ['Metron',
#   'Metron',
#   '',
#   'DC Comics',
#   '185.56999999999999',
#   '86.049999999999997',
#   'M',
#   '1971',
#   'Blue',
#   'Black',
#   '10',
#   'high'],
#  ['Meteorite', '', '', 'Marvel Comics', '', '', 'F', '', '', '', '', ''],
#  ['Michelangelo',
#   '',
#   '',
#   'IDW Publishing',
#   '',
#   '',
#   'M',
#   '',
#   'Blue',
#   '',
#   '15',
#   'good'],
#  ['Metamorpho',
#   'Rex Mason',
#   '',
#   'DC Comics',
#   '185.94',
#   '90.480000000000004',
#   'M',
#   '',
#   'Black',
#   'No Hair',
#   '85',
#   'good'],
#  ['Metallo',
#   'John Corben',
#   '',
#   'DC Comics',
#   '196.93000000000001',
#   '90.939999999999998',
#   'M',
#   '1987',
#   'Green',
#   'Brown',
#   '55',
#   'good'],
#  ['Mera',
#   'Mera',
#   '',
#   'DC Comics',
#   '175.36000000000001',
#   '72.75',
#   'F',
#   '1963',
#   'Blue',
#   'Red',
#   '65',
#   'average'],
#  ['Meltdown',
#   'Tabitha Smith ',
#   'Roanoke, Virginia ',
#   'Marvel Comics',
#   '165.31',
#   '54.5',
#   'F',
#   '',
#   'Blue',
#   'Blond',
#   '10',
#   'moderate'],
#  ['Mephisto',
#   '',
#   'Hell ',
#   'Marvel Comics',
#   '198.66',
#   '140.66',
#   'M',
#   '',
#   'White',
#   'Black',
#   '85',
#   'high'],
#  ['Maya Herrera',
#   'Maya Herrera',
#   'Dominican Republic',
#   'NBC - Heroes',
#   '',
#   '',
#   'F',
#   '',
#   '',
#   '',
#   '10',
#   'average'],
#  ['Maxima',
#   '',
#   'Almerac',
#   'DC Comics',
#   '180.75999999999999',
#   '72.849999999999994',
#   'F',
#   '',
#   'Brown',
#   'Red',
#   '90',
#   'good'],
#  ['Maverick',
#   'Christopher Bradley ',
#   '',
#   'Marvel Comics',
#   '193.06',
#   '110.36',
#   'M',
#   '1995',
#   'Blue',
#   'Black',
#   '10',
#   'good'],
#  ['Medusa',
#   'Medusalith Amaquelin Boltagon',
#   'Island of Attilan, Atlantic Ocean ',
#   'Marvel Comics',
#   '180.5',
#   '59.390000000000001',
#   'F',
#   '1965',
#   'Green',
#   'Red',
#   '35',
#   'good'],
#  ['Match',
#   'Kent Connor',
#   '',
#   'DC Comics',
#   '',
# ...
#   '',
#   'Marvel Comics',
#   '30.949999999999999',
#   '',
#   'M',
#   '1993',
#   'White',
#   'No Hair',
#   '75',
#   'average'],
#  ['Bloodaxe',
#   'Jackie Lukus',
#   '',
#   'Marvel Comics',
#   '218.06999999999999',
#   '495.32999999999998',
#   'F',
#   '',
#   'Blue',
#   'Brown',
#   '80',
#   'good'],
#  ['Blob',
#   'Frederick J. Dukes',
#   'Lubbock, Texas ',
#   'Marvel Comics',
#   '178.58000000000001',
#   '230.50999999999999',
#   'M',
#   '1964',
#   'Brown',
#   'Brown',
#   '85',
#   'low'],
#  ['Blizzard II',
#   'Donald Gill',
#   'Newark, Delaware',
#   'Marvel Comics',
#   '175.15000000000001',
#   '77.939999999999998',
#   'M',
#   '1987',
#   'Brown',
#   'Brown',
#   '10',
#   'moderate'],
#  ['Blizzard',
#   'Gregor Shapanka',
#   '',
#   'Marvel Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   'Brown',
#   '',
#   ''],
#  ['Blizzard', '', '', 'Marvel Comics', '', '', 'M', '', '', '', '', ''],
#  ['Blue Beetle II',
#   'Theodore Kord',
#   'Chicago, Illinois',
#   'DC Comics',
#   '183.84999999999999',
#   '86.890000000000001',
#   'M',
#   '1966',
#   'Blue',
#   'Brown',
#   '50',
#   'high'],
#  ['Blink',
#   'Clarice Ferguson',
#   'Bahamas',
#   'Marvel Comics',
#   '165.41',
#   '56.670000000000002',
#   'F',
#   '1994',
#   'Green',
#   'Magenta',
#   '10',
#   'average'],
#  ['Booster Gold',
#   'Michael Jon Carter',
#   'Gotham City, 25th Century',
#   'DC Comics',
#   '196.00999999999999',
#   '97.969999999999999',
#   'M',
#   '',
#   'Blue',
#   'Blond',
#   '85',
#   'good'],
#  ['Blaquesmith',
#   '',
#   '',
#   'Marvel Comics',
#   '',
#   '',
#   '',
#   '',
#   'Black',
#   'No Hair',
#   '',
#   ''],
#  ['Bolt', '', '', 'Marvel Comics', '', '', 'M', '', '', '', '', ''],
#  ['Bling!',
#   'Roxanne Washington ',
#   '',
#   'Marvel Comics',
#   '168.31',
#   '68.359999999999999',
#   'F',
#   '2005',
#   '',
#   '',
#   '15',
#   'good'],
#  ['Blackwulf',
#   'Lucian',
#   'Armechadon',
#   'Marvel Comics',
#   '188.16999999999999',
#   '88.640000000000001',
#   'M',
#   '1994',
#   'Red',
#   'White',
#   '30',
#   'average'],
#  ['Black Widow II',
#   'Yelena Belova',
#   '',
#   'Marvel Comics',
#   '170.25',
#   '61.850000000000001',
#   'F',
#   '',
#   'Blue',
#   'Blond',
#   '',
#   ''],
#  ['Blade',
#   'Eric Brooks',
#   'Soho, London,England',
#   'Marvel Comics',
#   '188.44999999999999',
#   '97.400000000000006',
#   'M',
#   '1973',
#   'Brown',
#   'Black',
#   '30',
#   'good'],
#  ['Blackout',
#   '',
#   '',
#   'Marvel Comics',
#   '191.19999999999999',
#   '104.09',
#   'M',
#   '1990',
#   'Red',
#   'White',
#   '35',
#   'good'],
#  ['Bloodhawk',
#   'Lemuel Krug',
#   '',
#   'Marvel Comics',
#   '',
#   '',
#   'M',
#   '2099',
#   'Black',
#   'No Hair',
#   '10',
#   'average'],
#  ['Blackwing',
#   'Joseph Manfredi',
#   'Professional Criminal',
#   'Marvel Comics',
#   '185.56',
#   '86.010000000000005',
#   'M',
#   '1975',
#   'Blue',
#   'Black',
#   '10',
#   'moderate'],
#  ['Black Mamba',
#   'Tanya Sealy',
#   'Chicago, Illinois',
#   'Marvel Comics',
#   '170.16999999999999',
#   '52.619999999999997',
#   'F',
#   '',
#   'Green',
#   'Black',
#   '10',
#   'good'],
#  ['Black Lightning',
#   'Jefferson Pierce',
#   '',
#   'DC Comics',
#   '185.34999999999999',
#   '90.590000000000003',
#   'M',
#   '1977',
#   'Brown',
#   'No Hair',
#   '15',
#   'average'],
#  ['Black Widow',
#   'Natasha Romanoff',
#   '',
#   'Marvel Comics',
#   '170.78999999999999',
#   '59.340000000000003',
#   'F',
#   '',
#   'Green',
#   'Auburn',
#   '15',
#   'good'],
#  ['Black Goliath', '', '', 'Marvel Comics', '', '', 'M', '', '', '', '', ''],
#  ['Black Cat',
#   'Felicia Hardy',
#   'Queens, New York',
#   'Marvel Comics',
#   '178.87',
#   '54.640000000000001',
#   'F',
#   '1979',
#   'Green',
#   'Blond',
#   '20',
#   'good'],
#  ['Black Flash',
#   '',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '10',
#   'average'],
#  ['Black Canary',
#   'Laurel Lance',
#   '',
#   'DC Comics',
#   '170.19999999999999',
#   '59.960000000000001',
#   'F',
#   '',
#   'Blue',
#   'Blond',
#   '10',
#   'good'],
#  ['Black Bolt',
#   'Blackagar Boltagon',
#   'Attilan, Atlantic Ocean ',
#   'Marvel Comics',
#   '188.97999999999999',
#   '95.799999999999997',
#   'M',
#   '1965',
#   'Blue',
#   'Black',
#   '70',
#   'good'],
#  ['Black Adam',
#   'Teth-Adam',
#   'Kahndaq, Egypt',
#   'DC Comics',
#   '191.41',
#   '113.34',
#   'M',
#   '1945',
#   'Brown',
#   'Black',
#   '100',
#   'high'],
#  ['Black Canary',
#   'Dinah Drake Lance',
#   '',
#   'DC Comics',
#   '165.36000000000001',
#   '58.649999999999999',
#   'F',
#   '1947',
#   'Blue',
#   'Blond',
#   '10',
#   'good'],
#  ['Bizarro',
#   'Bizarro',
#   '',
#   'DC Comics',
#   '191.0',
#   '155.56999999999999',
#   'M',
#   '1958',
#   'Black',
#   'Black',
#   '95',
#   'moderate'],
#  ['Black Abbott',
#   '',
#   '',
#   'Marvel Comics',
#   '',
#   '',
#   'M',
#   '1984',
#   'Red',
#   'Black',
#   '',
#   ''],
#  ['Bishop',
#   'Lucas Bishop',
#   'A mutant relocation camp in an undisclosed location on an alternate 21st Century Earth',
#   'Marvel Comics',
#   '198.68000000000001',
#   '124.27',
#   'M',
#   '1991',
#   'Brown',
#   'No Hair',
#   '15',
#   'good'],
#  ['Birdman',
#   'Ray Randal',
#   '',
#   'Hanna-Barbera',
#   '',
#   '',
#   'M',
#   '1967',
#   '',
#   '',
#   '55',
#   'high'],
#  ['Bird-Man',
#   'Henry Hawk',
#   '',
#   'Marvel Comics',
#   '',
#   '',
#   'M',
#   '1965',
#   '',
#   '',
#   '',
#   ''],
#  ['Bird-Man II',
#   'Achille DiBacco',
#   'The Bar with No Name, Medina County, Ohio ',
#   'Marvel Comics',
#   '',
#   '',
#   'M',
#   '1979',
#   '',
#   '',
#   '',
#   ''],
#  ['Bird-Brain',
#   '',
#   '',
#   'Marvel Comics',
#   '',
#   '',
#   '',
#   '1987',
#   '',
#   '',
#   '10',
#   'moderate'],
#  ['Black Manta',
#   'David',
#   '',
#   'DC Comics',
#   '188.12',
#   '92.780000000000001',
#   'M',
#   '1967',
#   'Black',
#   'No Hair',
#   '30',
#   'good'],
#  ['Binary',
#   'Carol Danvers',
#   'Boston, Massachusetts',
#   'Marvel Comics',
#   '180.34',
#   '54.359999999999999',
#   'F',
#   '',
#   'Blue',
#   'Blond',
#   '',
#   ''],
#  ['Billy Kincaid',
#   'Billy Kincaid',
#   '',
#   'Image Comics',
#   '',
#   '',
#   'M',
#   '1992',
#   '',
#   '',
#   '',
#   ''],
#  ['Bill Harken', '', '', 'SyFy', '', '', 'M', '', '', '', '40', 'good'],
#  ['Black Knight III',
#   'Dane Whitman',
#   'Gloucester, Massachusetts ',
#   'Marvel Comics',
#   '183.5',
#   '86.989999999999995',
#   'M',
#   '1967',
#   'Brown',
#   'Brown',
#   '10',
#   'good'],
#  ['Big Daddy',
#   'Damon Macready',
#   '',
#   'Icon Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '10',
#   'moderate'],
#  ['Big Man',
#   'Frederick Foswell',
#   '',
#   'Marvel Comics',
#   '165.33000000000001',
#   '71.0',
#   'M',
#   '1964',
#   'Blue',
#   'Brown',
#   '15',
#   'good'],
#  ['Big Barda',
#   'Barda Free',
#   '',
#   'DC Comics',
#   '188.53',
#   '135.38',
#   'F',
#   '',
#   'Blue',
#   'Black',
#   '100',
#   'high'],
#  ['Bionic Woman',
#   'Jamie Sommers',
#   '',
#   '',
#   '',
#   '',
#   'F',
#   '',
#   'Blue',
#   'Black',
#   '40',
#   'average'],
#  ['Ben 10',
#   'Benjamin Kirby Tennyson',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '10',
#   'low'],
#  ['Beta Ray Bill',
#   'Beta Ray Bill (translation of his Korbinite name)',
#   'Burning Galaxy',
#   'Marvel Comics',
#   '201.30000000000001',
#   '216.72999999999999',
#   'M',
#   '',
#   '',
#   'No Hair',
#   '80',
#   'good'],
#  ['Beetle', '', '', 'Marvel Comics', '', '', 'M', '', '', '', '', ''],
#  ['Beast',
#   'Henry Philip McCoy',
#   'Dunfee, Illinois',
#   'Marvel Comics',
#   '180.84999999999999',
#   '181.72999999999999',
#   'M',
#   '',
#   'Blue',
#   'Blue',
#   '50',
#   'high'],
#  ['Beast Boy',
#   'Garfield Mark Logan',
#   '',
#   'DC Comics',
#   '173.62',
#   '68.989999999999995',
#   'M',
#   '1965',
#   'Green',
#   'Green',
#   '30',
#   'average'],
#  ['Batwoman V',
#   'Katherine Rebecca Kane',
#   '',
#   'DC Comics',
#   '178.13999999999999',
#   '',
#   'F',
#   '2006',
#   'Green',
#   'Red',
#   '10',
#   'high'],
#  ['Batman II',
#   'Dick Grayson',
#   '',
#   'DC Comics',
#   '178.06999999999999',
#   '79.25',
#   'M',
#   '',
#   'Blue',
#   'Black',
#   '15',
#   'high'],
#  ['Batman',
#   'Terry McGinnis',
#   'Gotham City, 25th Century',
#   'DC Comics',
#   '178.03999999999999',
#   '77.879999999999995',
#   'M',
#   '',
#   'Blue',
#   'Black',
#   '40',
#   'high'],
#  ['Battlestar',
#   'Lemar Hoskins ',
#   'Chicago, Illinois ',
#   'Marvel Comics',
#   '198.53999999999999',
#   '133.03999999999999',
#   'M',
#   '1986',
#   'Brown',
#   'Black',
#   '55',
#   'average'],
#  ['Beyonder',
#   '',
#   'Created in the Beyond ',
#   'Marvel Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '100',
#   'high'],
#  ['Batgirl V',
#   'Charlotte Gage-Radcliffe',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'F',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Batgirl III',
#   'Helena Rosa Bertinelli',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'F',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Batman',
#   'Bruce Wayne',
#   'Crest Hill, Bristol Township; Gotham County',
#   'DC Comics',
#   '188.97',
#   '95.219999999999999',
#   'M',
#   '',
#   'blue',
#   'black',
#   '20',
#   'high'],
#  ['Batgirl VI',
#   'Stephanie Brown',
#   '',
#   'DC Comics',
#   '168.28999999999999',
#   '61.82',
#   'F',
#   '2009',
#   'Blue',
#   'Blond',
#   '10',
#   'good'],
#  ['Batgirl',
#   'Barbara Gordon',
#   '',
#   'DC Comics',
#   '170.12',
#   '57.100000000000001',
#   'F',
#   '',
#   'Green',
#   'Red',
#   '15',
#   'high'],
#  ['Batgirl',
#   'Mary Elizabeth Kane',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'F',
#   '',
#   '',
#   '',
#   '30',
#   'average'],
#  ['Bantam',
#   'Roberto Velasquez',
#   '',
#   'Marvel Comics',
#   '165.80000000000001',
#   '54.600000000000001',
#   'M',
#   '2006',
#   'Brown',
#   'Black',
#   '55',
#   'moderate'],
#  ['Banshee',
#   'Sean Cassidy',
#   'Cassidy Keep, Ireland',
#   'Marvel Comics',
#   '183.74000000000001',
#   '77.269999999999996',
#   'M',
#   '1967',
#   'Green',
#   'Strawberry Blond',
#   '10',
#   'average'],
#  ['Black Panther',
#   "T'Challa",
#   'Wakanda, Africa',
#   'Marvel Comics',
#   '183.03',
#   '90.5',
#   'M',
#   '1966',
#   'Brown',
#   'Black',
#   '20',
#   'high'],
#  ['Azrael',
#   'Michael Washington Lane',
#   'Gotham City ',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '2008',
#   'Brown',
#   'Black',
#   '20',
#   'good'],
#  ['Aztar',
#   'Aztar',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '1940',
#   '',
#   '',
#   '100',
#   'high'],
#  ['Beak',
#   'Barnell Bohusk ',
#   'Cheverly, Maryland ',
#   'Marvel Comics',
#   '175.30000000000001',
#   '63.090000000000003',
#   'M',
#   '',
#   'Black',
#   'White',
#   '',
#   ''],
#  ['Aurora',
#   'Jeanne-Marie Beaubier',
#   'Montreal, Quebec, Canada ',
#   'Marvel Comics',
#   '180.81',
#   '63.479999999999997',
#   'F',
#   '1979',
#   'Blue',
#   'Black',
#   '10',
#   'good'],
#  ['Azazel',
#   '',
#   'Isla des Demonas, Caribbean Sea',
#   'Marvel Comics',
#   '183.16',
#   '67.489999999999995',
#   'M',
#   '2003',
#   'Yellow',
#   'Black',
#   '15',
#   'average'],
#  ['Atom II',
#   'Ray Palmer',
#   '',
#   'DC Comics',
#   '183.43000000000001',
#   '81.349999999999994',
#   'M',
#   '',
#   'Brown',
#   'Auburn',
#   '10',
#   'high'],
#  ['Atom IV',
#   'Ryan Choi',
#   '',
#   'DC Comics',
#   '',
#   '72.069999999999993',
#   'M',
#   '',
#   'Brown',
#   'Black',
#   '',
#   ''],
#  ['Batgirl IV',
#   'Cassandra Cain',
#   'League of Assassins (exact base is unknown)',
#   'DC Comics',
#   '165.31999999999999',
#   '52.560000000000002',
#   'F',
#   '',
#   'Green',
#   'Black',
#   '15',
#   'good'],
#  ['Atom', '', '', 'DC Comics', '', '', 'M', '', '', '', '', ''],
#  ['Atom Girl',
#   'Salu Digby',
#   '',
#   'DC Comics',
#   '168.68000000000001',
#   '54.07',
#   'F',
#   '2004',
#   'Black',
#   'Black',
#   '10',
#   'moderate'],
#  ['Atlas',
#   '',
#   'Crystal Mountain',
#   'DC Comics',
#   '198.21000000000001',
#   '126.66',
#   'M',
#   '',
#   'Blue',
#   'Brown',
#   '100',
#   'good'],
#  ['Atom',
#   'Albert Pratt',
#   '',
#   'DC Comics',
#   '178.72999999999999',
#   '68.890000000000001',
#   'M',
#   '',
#   'Blue',
#   'Red',
#   '',
#   ''],
#  ['Arsenal',
#   'Roy William Harper, Jr.',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Atlas',
#   'Erik Josten',
#   'Milwaukee, Wisconsin',
#   'Marvel Comics',
#   '183.09',
#   '101.66',
#   'M',
#   '',
#   'Brown',
#   'Red',
#   '80',
#   'good'],
#  ['Armor',
#   'Hisako Ichiki',
#   '',
#   'Marvel Comics',
#   '163.33000000000001',
#   '50.390000000000001',
#   'F',
#   '2004',
#   'Black',
#   'Black',
#   '65',
#   'average'],
#  ['Bane',
#   '',
#   '',
#   'DC Comics',
#   '203.22',
#   '180.47999999999999',
#   'M',
#   '1993',
#   '',
#   '',
#   '40',
#   'high'],
#  ['Ardina',
#   'Ardina',
#   '',
#   'Marvel Comics',
#   '193.97999999999999',
#   '98.680000000000007',
#   'F',
#   '',
#   'White',
#   'Orange',
#   '100',
#   'good'],
#  ['Arclight',
#   'Philippa Sontag',
#   'Vietnam',
#   'Marvel Comics',
#   '173.43000000000001',
#   '57.25',
#   'F',
#   '1986',
#   'Violet',
#   'Purple',
#   '65',
#   'moderate'],
#  ['Ares',
#   '',
#   '',
#   'Marvel Comics',
#   '185.28',
#   '270.30000000000001',
#   'M',
#   '',
#   'Brown',
#   'Brown',
#   '85',
#   'good'],
#  ['Archangel',
#   'Warren Kenneth Worthington III ',
#   'Centerport, Long Island, New York ',
#   'Marvel Comics',
#   '183.81999999999999',
#   '68.629999999999995',
#   'M',
#   '1963',
#   'Blue',
#   'Blond',
#   '15',
#   'good'],
#  ['Astro Boy',
#   'Atom',
#   '',
#   '',
#   '',
#   '',
#   'M',
#   '',
#   'Brown',
#   'Black',
#   '95',
#   'average'],
#  ['Atom III',
#   'Adam Cray',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   'Red',
#   '',
#   ''],
#  ['Aqualad',
#   'Garth',
#   'Poseidonis, Atlantis',
#   'DC Comics',
#   '178.88999999999999',
#   '106.83',
#   'M',
#   '1960',
#   'Blue',
#   'Black',
#   '45',
#   'good'],
#  ['Ariel',
#   'Ariel',
#   '',
#   'Marvel Comics',
#   '165.34999999999999',
#   '59.170000000000002',
#   'F',
#   '1987',
#   'Purple',
#   'Pink',
#   '10',
#   'average'],
#  ['Aquababy',
#   'Arthur Curry, Jr.',
#   '',
#   'DC Comics',
#   '',
#   '',
#   'M',
#   '1965',
#   'Blue',
#   'Blond',
#   '20',
#   'low'],
#  ['Aquaman',
#   'Orin',
#   'Atlantis',
#   'DC Comics',
#   '185.71000000000001',
#   '146.96000000000001',
#   'M',
#   '1941',
#   'Blue',
#   'Blond',
#   '85',
#   'high'],
#  ['Apocalypse',
#   'En Sabah Nur',
#   'Akkaba, Egypt ',
#   'Marvel Comics',
#   '213.77000000000001',
#   '135.62',
#   'M',
#   '1986',
#   'Red',
#   'Black',
#   '100',
#   'high'],
#  ['Anti-Monitor',
#   '',
#   'Moon of Qward',
#   'DC Comics',
#   '61.369999999999997',
#   '',
#   'M',
#   '',
#   'Yellow',
#   'No Hair',
#   '100',
#   'high'],
#  ['Ant-Man II',
#   'Scott Lang',
#   'Coral Gables, Florida',
#   'Marvel Comics',
#   '183.66999999999999',
#   '86.280000000000001',
#   'M',
#   '1979',
#   'Blue',
#   'Blond',
#   '20',
#   'good'],
#  ['Anti-Venom',
#   'Eddie Brock',
#   'San Francisco, California',
#   'Marvel Comics',
#   '229.46000000000001',
#   '358.05000000000001',
#   'M',
#   '',
#   'Blue',
#   'Blond',
#   '60',
#   'good'],
#  ['Anti-Spawn',
#   'Jason Wynn',
#   '',
#   'Image Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '60',
#   'good'],
#  ['Annihilus',
#   'Annihilus',
#   'Planet of Arthros, Sector 17A, Negative Zone',
#   'Marvel Comics',
#   '180.94',
#   '90.109999999999999',
#   'M',
#   '1968',
#   'Green',
#   'No Hair',
#   '80',
#   'good'],
#  ['Angel',
#   'Warren Kenneth Worthington III',
#   'Centerport, Long Island, New York ',
#   'Marvel Comics',
#   '183.05000000000001',
#   '68.989999999999995',
#   'M',
#   '1969',
#   'Blue',
#   'Blond',
#   '15',
#   'good'],
#  ['Ammo',
#   '',
#   '',
#   'Marvel Comics',
#   '188.93000000000001',
#   '101.09',
#   'M',
#   '1988',
#   'Brown',
#   'Black',
#   '',
#   ''],
#  ['Arachne',
#   'Julia Carpenter',
#   'Los Angeles, California',
#   'Marvel Comics',
#   '175.15000000000001',
#   '63.75',
#   'F',
#   '',
#   'Blue',
#   'Blond',
#   '50',
#   'average'],
#  ['Angel',
#   'Liam',
#   '',
#   'Dark Horse Comics',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '30',
#   'good'],
#  ['Allan Quatermain', '', '', 'Wildstorm', '', '', 'M', '', '', '', '', ''],
#  ['Alien',
#   'Xenomorph',
#   'Your chest :)',
#   'Dark Horse Comics',
#   '244.30000000000001',
#   '169.66',
#   'M',
#   '1979',
#   '',
#   'No Hair',
#   '30',
#   'average'],
#  ['Alfred Pennyworth',
#   'Alfred Thaddeus Crane Pennyworth',
#   '',
#   'DC Comics',
#   '178.25999999999999',
#   '72.980000000000004',
#   'M',
#   '1943',
#   'Blue',
#   'Black',
#   '10',
#   'good'],
#  ['Ando Masahashi',
#   'Ando Masahashi',
#   '',
#   'NBC - Heroes',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Alex Woolsly',
#   'Alex Woolsly',
#   '',
#   'NBC - Heroes',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '40',
#   'average'],
#  ['Alan Scott',
#   'Alan Ladd Wellington Scott',
#   'Gotham City',
#   'DC Comics',
#   '180.97999999999999',
#   '90.810000000000002',
#   'M',
#   '1940',
#   'Blue',
#   'Blond',
#   '80',
#   'good'],
#  ['Amazo',
#   '',
#   '',
#   'DC Comics',
#   '257.49000000000001',
#   '173.94999999999999',
#   'M',
#   '1960',
#   'Red',
#   '',
#   '100',
#   'good'],
#  ['Ant-Man',
#   'Hank Pym',
#   'Elmsford, New York',
#   'Marvel Comics',
#   '211.74000000000001',
#   '122.44',
#   'M',
#   '1962',
#   'Blue',
#   'Blond',
#   '20',
#   'high'],
#  ['Ajax',
#   'Francis',
#   '',
#   'Marvel Comics',
#   '193.34',
#   '90.629999999999995',
#   'M',
#   '1998',
#   'Brown',
#   'Black',
#   '50',
#   'average'],
#  ['Alex Mercer',
#   'Alexander J. Mercer',
#   '',
#   'Wildstorm',
#   '',
#   '',
#   'M',
#   '',
#   '',
#   '',
#   '80',
#   'average']]

# %% [markdown]
# Va notato come pandas (così come, in generale, gran parte del software open source dedicato all'analisi dei dati) sia caratterizzato da una comunità di sviluppatori molto attiva. Ciò significa che il tempo tra il rilascio di due release successive sia di norma breve: se avete effettuato l'installazione in modo autonomo è quindi possibile che stiate utilizzando una versione più (o meno) recente di quella più aggiornata quando è stato scritto questo documento. Per verificare quale sia la versione installata è sufficiente accedere alla proprietà `pd.__version__`:

# %%
pd.__version__
# Out:
# '1.5.1'

# %% [markdown]
# Utilizzando una versione diversa da questa, può capitare che il risultato ottenuto eseguendo alcune celle sia diverso da quello indicato. Alcune funzionalità potrebbero anche non essere implementate, deprecate o perfino rimosse. Se state invece utilizzando l'ambiente fornito tramite immagine Docker o tramite mybinder non dovreste avere problemi di questo genere.

# %% [markdown]
# <div id="h-1"></div>
#
# ## Serie
# Una delle classi principali implementate in pandas è `Series`. Le sue istanze rappresentano serie di osservazioni di un certo carattere fatto su un insieme di individui. La cella seguente recupera dalla lista `heroes` precedentemente creata i nomi dei supereoi e il loro anno di prima apparizione e li utilizza per creare una serie:

# %%
years = [int(h[7]) if h[7] else None for h in heroes]
names = [h[0] for h in heroes]
first_appearance = pd.Series(years, index = names)

# %% [markdown]
# Nella creazione della lista `year` è stata utilizzata una list comprehension in cui l'espressione `int(h[7]) if h[7] else None` utilizza un operatore ternario tramite cui la stringa vuota viene trasformata nel valore speciale `None`, mentre tutte le altre vengono convertite nel corrispondente intero.
#
# La differenza tra una serie e una lista o una tupla è legata alla possibilità di invocare su di essa delle funzioni specifiche. Inoltre a ogni serie è associato un *indice* che permette di identificare ogni elemento osservato. Nell'esempio sopra riportato, il primo argomento specificato nel costruttore è una lista (ma sarebbe andata bene anche una tupla) di anni che indicano la prima apparizione di un supereroe e il secondo rappresenta appunto l'indice, che in questo caso è la lista dei corrispondenti nomi. Quando si visualizza una serie, ogni osservazione viene associata al corrispondente elemento usando appunto l'indice:

# %%
first_appearance
# Out:
# A-Bomb         2008.0
# Abraxas           NaN
# Abomination       NaN
# Adam Monroe       NaN
# Agent 13          NaN
#                 ...
# Alan Scott     1940.0
# Amazo          1960.0
# Ant-Man        1962.0
# Ajax           1998.0
# Alex Mercer       NaN
# Length: 735, dtype: float64

# %% [markdown]
# La visualizzazione della serie (che in questo caso riporta solo i primi e gli ultimi elementi perché la serie è troppo lunga) termina indicando il tipo di dato usato per rappresentare le varie osservazioni. Nell'esempio precedente viene utilizzato il tipo `float64` (pandas utilizza internamente gli array di numpy, in cui è presente un'implementazione dei tipi in virgola mobile diversa da quella standard di python), nonostante i dati originari fossero numeri interi. Ciò è dovuto alla presenza di valori mancanti. Di norma vengono indicati con la sigla NA (dall'inglese "not available"), ma in pandas essi vengono rappresentati utilizzando il concetto di "not a number" dello standard IEEE per la virgola mobile: si noti come tutte le occorrenze di `None` nella lista originale siano state automaticamente convertite in `np.nan`.
#
# L'accesso ai dati contenuti in una serie può avvenire in due modi:
# - specificando un valore per l'indice tra parentesi quadre dopo la serie o dopo la sua proprietà `loc`:

# %%
(first_appearance['Wonder Woman'], first_appearance.loc['Wonder Woman'])
# Out:
# (1941.0, 1941.0)

# %% [markdown]
# - indicando un valore per la posizione tra parentesi quadre dopo la serie o dopo la sua proprietà `iloc`:

# %%
(first_appearance[128], first_appearance.iloc[128])
# Out:
# (1992.0, 1992.0)

# %% [markdown]
# <div class="alert alert-warning">
# Se l'indice di una serie è basato su valori interi, i valori tra parentesi quadre immediatamente dopo la serie faranno riferimento all'indice e non alla posizione: ciò potrebbe essere fuorviante se gli elementi dell'indice non partono da zero e non sono consecutivi.
# </div>

# %% [markdown]
# È inoltre possibile utilizzare una notazione simile al _list slicing_ specificando valori dell'indice oppure posizioni. Va però notato che gli _slicing_ basati su indice comprenderanno il primo e l'ultimo valore specificato:

# %%
first_appearance['Wonder Girl':'Wonder Woman']
# Out:
# Wonder Girl     1996.0
# Wonder Woman    1941.0
# dtype: float64

# %% [markdown]
# mentre gli _slice_ basati su posizione escluderanno l'ultimo elemento:

# %%
first_appearance[60:63]
# Out:
# Vegeta         NaN
# Vixen       1981.0
# Valkyrie       NaN
# dtype: float64

# %% [markdown]
# L'accesso posizionale può anche fare riferimento a numeri negativi, contando in analogia a liste e tuple a partire dall'ultimo elemento:

# %%
first_appearance[-5:]
# Out:
# Alan Scott     1940.0
# Amazo          1960.0
# Ant-Man        1962.0
# Ajax           1998.0
# Alex Mercer       NaN
# dtype: float64

# %% [markdown]
# È possibile accedere ai primi e ultimi elementi di una serie anche utilizzando le funzioni `head` e `tail`, che mostrano rispettivamente solo le prime e le ultime righe:

# %%
first_appearance.head(7)
# Out:
# A-Bomb         2008.0
# Abraxas           NaN
# Abomination       NaN
# Adam Monroe       NaN
# Agent 13          NaN
# Air-Walker        NaN
# Agent Bob      2007.0
# dtype: float64

# %% [markdown]
# L'accesso alle liste può anche essere fatto specificando una lista (ma non una tupla) di posizioni al posto di una sola posizione, con l'effetto di ottenere i corrispondenti elementi.

# %%
first_appearance[[1, 42, 709]]
# Out:
# Abraxas     NaN
# Warbird     NaN
# Astro Boy   NaN
# dtype: float64

# %% [markdown]
# Questo tipo di accesso può essere fatto anche specificando una lista di valori per l'indice. Infine, si può utilizzare una lista di valori booleani in cui `True` indica gli elementi da estrarre e `False` quelli da filtrare:

# %%
first_appearance[[1970 <= y <1975 for y in first_appearance]]
first_appearance
# Out:
# A-Bomb         2008.0
# Abraxas           NaN
# Abomination       NaN
# Adam Monroe       NaN
# Agent 13          NaN
#                 ...
# Alan Scott     1940.0
# Amazo          1960.0
# Ant-Man        1962.0
# Ajax           1998.0
# Alex Mercer       NaN
# Length: 735, dtype: float64

# %% [markdown]
# <div class="alert alert-warning">
# L'uso di questa modalità di accesso richiede che la lista di valori booleani abbia la stessa lunghezza della serie. L'uso di liste di dimensioni minori l'accesso, che comporta un filtraggio effettuato solo nei primi elementi della serie, è deprecato e va quindi evitato.
# </div>

# %% [markdown]
# Infine, è possibile effettuare delle _query_ su una serie specificando tra parentesi quadre un'espressione logica che indica quali elementi visualizzare, utilizzando la serie come simbolo che ne indica un suo generico elemento:

# %%
first_appearance[first_appearance > 2010]
# Out:
# Venompool        2011.0
# The Cape         2011.0
# Spider-Man       2011.0
# Simon Baz        2012.0
# Rey              2015.0
# Kylo Ren         2015.0
# Jyn Erso         2016.0
# K-2SO            2016.0
# Jessica Cruz     2013.0
# Garbage Man      2011.0
# Evil Deadpool    2011.0
# Captain Cold     2012.0
# Bloodhawk        2099.0
# dtype: float64

# %% [markdown]
# <div class="alert alert-info">
# Tecnicamente, l'espressione `first_appearance > 2010` genera una nuova serie che ha lo stesso indice di `first_appearance` e in cui i valori sono `True` in corrispondenza degli anni successivi al 2010 e `False` altrimenti. Questa nuova serie viene utilizzata per filtrare `first_appearance`.
# </div>

# %% [markdown]
# Vediamo ora come utilizzando le serie sia molto più semplice calcolare e visualizzare le frequenze assolute: il metodo `value_counts` **restituisce un'altra serie in cui gli indici sono i valori osservati e i valori le corrispondenti frequenze assolute, ordinate in senso non crescente.**

# %%
first_appearance.value_counts()
# Out:
# 1964.0    18
# 1963.0    18
# 1965.0    14
# 2004.0    11
# 1975.0    10
#           ..
# 2013.0     1
# 1983.0     1
# 1933.0     1
# 1948.0     1
# 1988.0     1
# Length: 71, dtype: int64

# %% [markdown]
# Va notato come il tipo delle frequenze sia, correttamente, intero e come i valori mancanti siano automaticamente esclusi dal calcolo delle frequenze, mentre sono sempre presenti gli _outlier_.  Per ottenere una serie i cui elementi siano ordinati per valore non decrescente della voce nell'indice è sufficiente invocare il metodo `sort_index`; già che ci siamo, è un buon momento per eliminare i valori fuori scala dal conteggio effettuando una _query_ sulla serie:

# %%
first_app_freq = first_appearance[first_appearance < 2090].value_counts().sort_index()
first_app_freq.head(10)
# Out:
# 1933.0    1
# 1939.0    1
# 1940.0    9
# 1941.0    7
# 1943.0    2
# 1944.0    2
# 1945.0    1
# 1947.0    2
# 1948.0    1
# 1950.0    1
# dtype: int64

# %% [markdown]
# `first_appearance[first_appearance < 2090]` è una query che combino con uil metodo `value_counts()` e poi li ordino con `sort_index()` ossia sull'anno non sul valore. Per ciò`first_app_freq` è una serie di dati che contiene i valori assoluti delle frequenze.

# %% [markdown]
# <div id="h-2"></div>
#
# ## Visualizzione grafica di una serie
# Pandas mette a disposizione l'oggetto `plot` per visualizzare graficamente i contenuti di una serie, utilizzando matplotlib dietro le quinte; in particolare, il metodo `bar` visualizza un grafico a barre:

# %%
# Don't try this at home (men che meno all'esame!)

first_appearance.plot.bar()
plt.show()

# %% [markdown]
# Il grafico ottenuto, diciamolo, **fa schifo**. Questo perché **`bar` considera un punto per ogni elemento della serie, in cui le ascisse corrispondono alla posizione** (zero per la prima osservazione, uno per la seconda e così via, sebbene nel grafico sull'asse delle ascisse vengano poi visualizzati i valori dell'indice) e le **ordinate al valore osservato**. Per ognuno dei punti così ottenuti viene poi tracciato un segmento che lo congiunge perpendicolarmente all'asse delle ascisse. Il risultato è decisamente poco informativo, sia da un punto di vista grafico (le etichette sull'asse delle ascisse si sovrappongono, così che non si riesce a leggere nulla), sia da un punto di vista analitico: le barre hanno altezze simili e quindi le loro differenze sono poco apprezzabili a colpo d'occhio; inoltre il grafico dipende per esempio dall'ordine in cui sono elencate le osservazioni e non ci permette di solito di trarre alcuna informazione sulla relazione che lega tra loro le osservazioni.
#
# Si ottengono dei risultati decisamente più interessanti se si visualizza un grafico analogo per le **frequenze assolute**.
# Le grafico così:

# %%
first_app_freq.plot.bar()
plt.show()

# %% [markdown]
# Il grafico ottenuto è sicuramente migliore di quello precedente, ma rimane il problema di leggibilità dell'asse delle ascisse. Ciò è dovuto al fatto che pandas non inserisce le barre sul grafico nelle ascisse corrispondenti agli anni, ma le posiziona una accanto all'altra, come possiamo renderci conto visualizzando un po' meglio solo alcune delle etichette (in prima istanza non è importante capire come venga generato questo grafico, ma se siete cursosi potete leggere l'approfondimento che trovate dopo il commento al grafico stesso):

# %%
years = np.arange(1945, 2010, 10)
index_pos = [first_app_freq.index.get_loc(y) for y in years]
index_pos
# Out:
# [6, 11, 20, 30, 40, 50, 59]

# %% [markdown]
# Query che restituisce una lista in cui ogni posizione è il valore assoluto delle frequenze nelgi anni.
#
# Così posso dare all'ascissa il mio `index_pos` e `years` all'ordinata. in questo caso le ascisse per me sono gli indici

# %%
first_app_freq.plot.bar()
plt.xticks(index_pos, years) #metodi di aspetto grafico
plt.ylim((0, 18.5))
plt.show()

# %% [markdown]
# Problematica è la visualizzazione perchè ho una barra per ogni osservazione. infatti gli anni non sono distaccati ugualmente. Per ciò uso direttamente `matplotlib` rendendo *inutile* ciò che abbiamo fatto.
#
# Si può osservare che tra due valori successivi evidenziati nell'asse delle ascisse intercorre una distanza di dieci anni, ma le etichette non risultano equispaziate: ciò è dovuto al fatto che in realtà la prima barra ha ascissa 1, la seconda ha ascissa 2 e così via, mentre le etichette mostrate sull'asse delle ascisse corrispondono ai valori degli indici.
#
# <div class="alert alert-info">
# Per generare il grafico precedente è necessario utilizzare alcune funzionalità avanzate delle librerie considerate: `np.arange` permette di costruire un array i cui valori vanno di dieci in dieci partendo da 1945 e arrivando a 2005; la proprietà `index` di una serie permette di estrarne l'indice e il metodo `get_loc` di quest'ultimo restituisce la posizione corrispondente a un dato valore dell'indice. Infine, il metodo `xticks` di matplotlib permette di specificare quali valori evidenziare sull'asse delle ascisse e quali etichette utilizzare.
# </div>
#
# Per ottenere un grafico simile in cui le ascisse siano effettivamente gli anni di prima apparizione è necessario tornare a utilizzare esplicitamente `matplotlib`, passando al metodo `bar` rispettivamente l'indice e i valori della serie, che si ottengono rispettivamente utilizzando la proprietà `index` e invocando il metodo `get_values`.

# %%
plt.bar(first_app_freq.index, first_app_freq.values) #grafico a barre con indice (anni) sull'asse X e la frenquenza di apparizione sull'asse Y.
plt.xlim((1935, 2015))
plt.ylim(0, 18.5)
plt.show()

# %% [markdown]
# <div id="h-3"></div>
#
# ## Operazioni con le serie
# Consideriamo le seguenti domande:
#
# 1. Quanti supereroi sono apparsi a partire dal 1960?
# 2. Quanti tra il 1940 e il 1965?
# 3. Quanti prima del 1970?
#
# Per rispondere alla prima domanda dobbiamo isolare le frequenze che corrispondono agli anni di apparizione che vanno dal 1960 in avanti. Notiamo che l'indice della serie contiene i valori degli anni; è quindi possibile utilizzare l'accesso tramite *list slicing* per recuperare le frequenze degli anni di apparizione che vanno dal 1960 in avanti:

# %%
first_app_freq[1960:]
# Out:
# 1960.0     8
# 1961.0     3
# 1962.0     4
# 1963.0    18
# 1964.0    18
# 1965.0    14
# 1966.0     6
# 1967.0     8
# 1968.0     5
# 1969.0     2
# 1970.0     2
# 1971.0     5
# 1972.0     9
# 1973.0     4
# 1974.0     2
# 1975.0    10
# 1976.0    10
# 1977.0    10
# 1978.0     1
# 1979.0     9
# 1980.0     9
# 1981.0     8
# 1982.0     2
# 1983.0     1
# 1984.0     6
# 1985.0     9
# 1986.0    10
# 1987.0     9
# 1988.0     1
# 1989.0     5
# 1990.0     4
# 1991.0     5
# 1992.0     9
# 1993.0    10
# 1994.0    10
# 1995.0     5
# 1996.0     2
# 1997.0     4
# 1998.0     4
# 1999.0     5
# 2000.0     3
# 2001.0     3
# 2003.0     4
# 2004.0    11
# 2005.0     7
# 2006.0     7
# 2007.0     5
# 2008.0     6
# 2009.0     1
# 2010.0     4
# 2011.0     5
# 2012.0     2
# 2013.0     1
# 2015.0     2
# 2016.0     2
# dtype: int64

# %% [markdown]
# A questo punto è sufficiente invocare la funzione `sum` sulla sotto-serie individuata per ottenere la somma delle frequenze:

# %%
sum(first_app_freq[1960:])
# Out:
# 329

# %% [markdown]
# La seconda domanda trova risposta in modo analogo, filtrando le frequenze degli anni di apparizione tra il 1940 e il 1966:

# %%
sum(first_app_freq[1940:1966])
# Out:
# 106

# %% [markdown]
# Analogamente, all'ultima domanda si risponde selezionando gli anni fino al 1969:

# %%
sum(first_app_freq[:1970])
# Out:
# 125

# %% [markdown]
# <div class="alert alert-info">
# La funzione `sum` accetta come argomento liste, tuple e serie: in tutti i casi restituisce la somma dei valori in esse contenute.
# </div>
#
# Un modo alternativo per calcolare la somma dei valori in una serie è quella di invocare su di essa l'omonimo metodo `sum`. Le serie sono inoltre in tutto e per tutto dei vettori, sui quali è possibile effettuare operazioni algebriche. Consideriamo per esempio le due serie contenenti altezza e peso dei supereroi:

# %%
with open('data/heroes.csv', 'r') as heroes_file:
  heroes_reader = csv.reader(heroes_file, delimiter=';', quotechar='"')
  heroes = list(heroes_reader)[1:]
heroes[:1]
# Out:
# [['A-Bomb',
#   'Richard Milhouse Jones',
#   'Scarsdale, Arizona',
#   'Marvel Comics',
#   '203.21000000000001',
#   '441.94999999999999',
#   'M',
#   '2008',
#   'Yellow',
#   'No Hair',
#   '100',
#   'moderate']]

# %%
#serie che tira fuori il peso e altezza degli eroi per ogni eroe dandole come indice il nome degli eroi
height = pd.Series([float(h[4]) if h[4] else None for h in heroes], index=names) 
weight = pd.Series([float(h[5]) if h[5] else None for h in heroes], index=names)

# %% [markdown]
# Una prima categoria di operazioni è quella che si ottiene indicando il nome di una serie all'interno di un'espressione aritmetica: il risultato è una nuova serie ottenuta calcolando l'espressione su tutti gli elementi della serie di partenza. Per esempio, la cella seguente crea la serie contenente l'altezza degli eroi misurata in metri e ne visualizza i primi dieci elementi:

# %%
(height/100)[:10] #nuova serie con stesso indice e valore è come l'originale ma `/100`
# Out:
# A-Bomb         2.0321
# Abraxas           NaN
# Abomination    2.0304
# Adam Monroe       NaN
# Agent 13       1.7341
# Air-Walker     1.8859
# Agent Bob      1.7825
# Abe Sapien     1.9124
# Abin Sur       1.8552
# Angela            NaN
# dtype: float64

# %% [markdown]
# Quando si considerano operazioni più complicate, è possibile utilizzare il metodo `apply` indicando come suo argomento la funzione da applicare agli elementi della serie. Per esempio, nella cella seguente viene **creata una nuova serie ottenuta esprimendo le altezze dei supereroi in metri e successivamente elevando il risultato al quadrato**.

# %%
height.apply(lambda h: (h/100)**2)[:10]
# Out:
# A-Bomb         4.129430
# Abraxas             NaN
# Abomination    4.122524
# Adam Monroe         NaN
# Agent 13       3.007103
# Air-Walker     3.556619
# Agent Bob      3.177306
# Abe Sapien     3.657274
# Abin Sur       3.441767
# Angela              NaN
# dtype: float64

# %% [markdown]
# Un'altra importante categoria di operazioni è quella che vede due serie indicate come argomenti di un operatore aritmetico binario. In questo caso verrà ancora creata una nuova serie, in cui l'operazione viene calcolata elemento per elemento nelle serie indicate. Per esempio, la cella seguente crea una nuova serie `bmi` contenente l'indice di massa corporea (BMI) dei supereroi (ottenuto dividendo il peso specificato in chilogrammi per il quadrato dell'altezza misurata in metri), e mostra i quindici supereroi con il BMI più elevato.

# %%
bmi = weight / height.apply(lambda h: (h/100)**2)
bmi.sort_values(ascending=False)[:15]
# Out:
# Utgard-Loki     2501.321629
# Giganta         1607.124545
# Red Hulk         137.611973
# Darkseid         114.366701
# Machine Man      114.083519
# Thanos           109.414534
# Destroyer        107.579152
# Abomination      107.211015
# A-Bomb           107.024446
# Hulk             105.622909
# Bloodaxe         104.160435
# Juggernaut       103.216295
# King Kong        102.732873
# Sasquatch         96.810738
# Living Brain      91.318046
# dtype: float64

# %% [markdown]
# A parte notare Hulk è solo il quindicesimo della classifica, va sottolinato che le operazioni fatte elemento per elemento allineano i vettori corrispondenti alle serie in base all'indice (e non alla posizione). Consideriamo per esempio la seguente cella, in cui vengono selezionati altezze e pesi più o meno plausibili per un essere umano, calcolando poi i corrispondenti BMI (indice massa corporea).
#
# Estrapolo da una serie dei valori che rispettano le condizioni e genero un'altra serie con stesso indice:

# %%
standard_weight = weight[(weight < 100) & (weight > 40)]
standard_height = height[(height < 210) & (height > 120)]/100
(standard_weight / (standard_height**2))[:15]
# Out:
# A-Bomb                     NaN
# Abe Sapien           17.868501
# Abin Sur             26.410852
# Abomination                NaN
# Absorbing Man              NaN
# Adam Strange         25.952943
# Agent 13             20.295282
# Agent Bob            25.634923
# Agent Zero                 NaN
# Air-Walker                 NaN
# Ajax                 24.245355
# Alan Scott           27.725061
# Alfred Pennyworth    22.966566
# Ammo                       NaN
# Angel                20.589542
# dtype: float64

# %% [markdown]
# Si nota un numero relativamente elevato di `NaN`, e ciò è appunto dovuto al fatto che il rapporto alla base del calcolo del BMI viene fatto usando peso e altezza di valori che hanno lo stesso indice. Ora, **non è detto che un supereroe che ha un peso plausibile abbia anche un'altezza plausibile, e viceversa**. Quello che succede quando si esegue un'operazione tra due serie e solo una di essa è definita in corrispondenza di uno specifico valore dell'indice, **il risultato conterrà `NaN` per quel valore.**

# %% [markdown]
# <div id="h-4"></div>
#
# ## Dataframe
# Un _dataframe_ è una collezione di serie che hanno lo stesso indice, ed è quindi un insieme di osservazioni di vari _caratteri_ per una popolazione di individui. Tra i vari modi che sono disponibili in pandas per creare un _dataframe_, noi faremo riferimento al metodo `read_csv` della classe `pd.DataFrame`, **che permette di leggere i contenuti di un file in formato CSV e convertirli automaticamente in un _dataframe_.**

# %%
heroes = pd.read_csv('data/heroes.csv', sep=';', index_col=0)

# %% [markdown]
# Specifico che la *zeeresima* colonna è l'indice.
#
# Notar bene inoltre che il metodo `read_csv` converte certe variabili in Float.

# %% [markdown]
# Usando lo stesso file a cui abbiamo fatto riferimento nei paragrafi precedenti, è stato necessario utilizzare l'argomento opzionle `sep` per indicare il carattere usato per separare i campi in ogni record. La visualizzazione dei dataframe viene automaticamente formattata in un formato tabellare facile da leggere se si utilizza jupyter:

# %%
heroes
# Out:
#                                Identity         Birth place      Publisher  \
# Name
# A-Bomb           Richard Milhouse Jones  Scarsdale, Arizona  Marvel Comics
# Abraxas                         Abraxas    Within Eternity   Marvel Comics
# Abomination                Emil Blonsky  Zagreb, Yugoslavia  Marvel Comics
# Adam Monroe                         NaN                 NaN   NBC - Heroes
# Agent 13                  Sharon Carter                 NaN  Marvel Comics
# ...                                 ...                 ...            ...
# Alan Scott   Alan Ladd Wellington Scott         Gotham City      DC Comics
# Amazo                               NaN                 NaN      DC Comics
# Ant-Man                        Hank Pym  Elmsford, New York  Marvel Comics
# Ajax                            Francis                 NaN  Marvel Comics
# Alex Mercer         Alexander J. Mercer                 NaN      Wildstorm
#
#              Height  Weight Gender  First appearance Eye color Hair color  \
# Name
# A-Bomb       203.21  441.95      M            2008.0    Yellow    No Hair
# Abraxas         NaN     NaN      M               NaN      Blue      Black
# Abomination  203.04  441.98      M               NaN     Green    No Hair
# Adam Monroe     NaN     NaN      M               NaN      Blue      Blond
# Agent 13     173.41   61.03      F               NaN      Blue      Blond
# ...             ...     ...    ...               ...       ...        ...
# Alan Scott   180.98   90.81      M            1940.0      Blue      Blond
# Amazo        257.49  173.95      M            1960.0       Red        NaN
# Ant-Man      211.74  122.44      M            1962.0      Blue      Blond
# Ajax         193.34   90.63      M            1998.0     Brown      Black
# Alex Mercer     NaN     NaN      M               NaN       NaN        NaN
#
#              Strength Intelligence
# Name
# A-Bomb          100.0     moderate
# Abraxas         100.0         high
# Abomination      80.0         good
# Adam Monroe      10.0         good
# Agent 13          NaN          NaN
# ...               ...          ...
# Alan Scott       80.0         good
# Amazo           100.0         good
# Ant-Man          20.0         high
# Ajax             50.0      average
# Alex Mercer      80.0      average
#
# [735 rows x 11 columns]

# %% [markdown]
# Ci riferiremo spesso alle r**ighe e alle colonne di un _dataframe_ per indicare rispettivamente le osservazioni e i caratteri**. Per esempio la prima riga si riferisce all'osservazione relativa ad "A-Bomb", mentre la prima colonna corrisponde al carattere "identity". Vi sono molti modi per interagire con un _dataframe_:
#
# - l'insieme degli indici, dei caratteri e dei valori si ottengono, nell'ordine, alle proprietà `index`, `columns` e `values`;
# - una serie corrispondente a una colonna/carattere può essere selezionata usando una sintassi simile a quella dei dizionari, specificando il nome del carattere come chiave:
#
# **Insomma il mio operatore d'accesso sono i miei indici** per le colonne.

# %%
heroes['Gender']
# Out:
# Name
# A-Bomb         M
# Abraxas        M
# Abomination    M
# Adam Monroe    M
# Agent 13       F
#               ..
# Alan Scott     M
# Amazo          M
# Ant-Man        M
# Ajax           M
# Alex Mercer    M
# Name: Gender, Length: 735, dtype: object

# %% [markdown]
# In alternativa è possibile usare una sintassi basata su _dot notation_ in cui il nome della colonna, senza essere racchiuso tra apici, segue il _dataframe_. In altre parole, `heroes['Gender']` e `heroes.Gender` sono equivalenti. *Questa seconda notazione è però utilizzabile solamente se non vi sono spazi nei nomi delle colonne. Nel seguito utilizzeremo quindi sempre la prima delle due notazioni*.

# %% [markdown]
# - tramite uno _slicing_ sulle posizioni o sui valori dell'indice è possibile selezionare un sottoinsieme delle righe del _dataframe_ (e come nel caso delle serie, l'estremo superiore è incluse se si usano gli indici ed escluso se si usano le posizioni):
#
# **Con lo slicing accedo alle righe**.

# %%
heroes['Agent 13':'Ajax']
# Out:
#                                 Identity  \
# Name
# Agent 13                   Sharon Carter
# Air-Walker                   Gabriel Lan
# Agent Bob                            Bob
# Abe Sapien                Abraham Sapien
# Abin Sur                             NaN
# ...                                  ...
# Alex Woolsly                Alex Woolsly
# Alan Scott    Alan Ladd Wellington Scott
# Amazo                                NaN
# Ant-Man                         Hank Pym
# Ajax                             Francis
#
#                                                     Birth place  \
# Name
# Agent 13                                                    NaN
# Air-Walker    Xandar, a planet in the Tranta system, Androme...
# Agent Bob                                                   NaN
# Abe Sapien                                                  NaN
# Abin Sur                                                 Ungara
# ...                                                         ...
# Alex Woolsly                                                NaN
# Alan Scott                                          Gotham City
# Amazo                                                       NaN
# Ant-Man                                      Elmsford, New York
# Ajax                                                        NaN
#
#                       Publisher  Height  Weight Gender  First appearance  \
# Name
# Agent 13          Marvel Comics  173.41   61.03      F               NaN
# Air-Walker        Marvel Comics  188.59  108.23      M               NaN
# Agent Bob         Marvel Comics  178.25   81.45      M            2007.0
# Abe Sapien    Dark Horse Comics  191.24   65.35      M            1993.0
# Abin Sur              DC Comics  185.52   90.90      M            1959.0
# ...                         ...     ...     ...    ...               ...
# Alex Woolsly       NBC - Heroes     NaN     NaN      M               NaN
# Alan Scott            DC Comics  180.98   90.81      M            1940.0
# Amazo                 DC Comics  257.49  173.95      M            1960.0
# Ant-Man           Marvel Comics  211.74  122.44      M            1962.0
# Ajax              Marvel Comics  193.34   90.63      M            1998.0
#
#              Eye color Hair color  Strength Intelligence
# Name
# Agent 13          Blue      Blond       NaN          NaN
# Air-Walker        Blue      White      85.0      average
# Agent Bob        Brown      Brown      10.0          low
# Abe Sapien        Blue    No Hair      30.0         high
# Abin Sur          Blue    No Hair      90.0      average
# ...                ...        ...       ...          ...
# Alex Woolsly       NaN        NaN      40.0      average
# Alan Scott        Blue      Blond      80.0         good
# Amazo              Red        NaN     100.0         good
# Ant-Man           Blue      Blond      20.0         high
# Ajax             Brown      Black      50.0      average
#
# [730 rows x 11 columns]

# %% [markdown]
# Queste modalità di accesso possono effettivamente creare confusione: usando una sintassi molto simile, specificando un valore si accede a una colonna e specificando uno _slice_ si accede a un insieme di righe. Per scrivere codice più chiaro è meglio selezionare le righe utilizzando le proprietà `loc` e `iloc` nello stesso modo in cui queste funzionano per le serie, con la differenza che **quando queste sono usate specificando un solo valore, viene restituita una serie, e quando sono utilizzate con uno _slice_ o con una lista viene restituito un _dataframe_.**

# %%
heroes.loc['Professor X']
# Out:
# Identity            Charles Francis Xavier
# Birth place             New York, New York
# Publisher                    Marvel Comics
# Height                              183.74
# Weight                               86.89
# Gender                                   M
# First appearance                    1963.0
# Eye color                             Blue
# Hair color                         No Hair
# Strength                              10.0
# Intelligence                          high
# Name: Professor X, dtype: object

# %%
heroes.iloc[42:46] #Qua accedo alle righe
# Out:
#                  Identity                    Birth place      Publisher  \
# Name
# Warbird     Carol Danvers          Boston, Massachusetts  Marvel Comics
# Wildfire  Drake Burroughs                            NaN      DC Comics
# Vulture     Adrian Toomes  Staten Island, New York City   Marvel Comics
# Warp         Emil LaSalle                            NaN      DC Comics
#
#           Height  Weight Gender  First appearance Eye color Hair color  \
# Name
# Warbird   180.56   54.75      F               NaN      Blue      Blond
# Wildfire     NaN     NaN      M               NaN       NaN        NaN
# Vulture   180.61   79.63      M               NaN     Brown    No Hair
# Warp      173.42   67.42      M            1981.0     Brown      Black
#
#           Strength Intelligence
# Name
# Warbird        NaN          NaN
# Wildfire      35.0      average
# Vulture       25.0         good
# Warp          10.0     moderate

# %% [markdown]
# È inoltre possibile selezionare una o più righe e visualizzare solo un sottoinsieme dei caratteri, passando a `loc` o `iloc` un secondo argomento in cui si specificano i caratteri da mostrare, utilizzando anche in questo caso un valore, una lista di valori oppure uno _slice_:

# %%
heroes.loc['Professor X' : 'Ajax', 'Height':'Weight'] #qua accedo alle colonne
# Out:
#               Height  Weight
# Name
# Professor X   183.74   86.89
# Proto-Goblin     NaN     NaN
# Predator      213.59  234.19
# Power Man        NaN     NaN
# Polaris       170.90   52.89
# ...              ...     ...
# Alex Woolsly     NaN     NaN
# Alan Scott    180.98   90.81
# Amazo         257.49  173.95
# Ant-Man       211.74  122.44
# Ajax          193.34   90.63
#
# [513 rows x 2 columns]

# %% [markdown]
# Va notato che `loc` accetta solo valori simbolici, mentre `iloc` solamente posizioni, e ciò riguarda anche il loro secondo argomento:

# %%
heroes.iloc[[106, 103], [3, 4]]
# Out:
#            Height  Weight
# Name
# Tempest    163.02   54.36
# Supergirl  165.40   54.80

# %% [markdown]
# Volendo accedere direttamente a un elemento è possibile utilizzare le proprietà `at` e `iat` (più efficiente).:

# %%
heroes.at['Superman', 'Strength']
# Out:
# 100.0

# %%
heroes.iat[500, -1]
# Out:
# 'high'

# %% [markdown]
# <div class="alert alert-info">
# È anche possibile utilizzare `loc` e `iloc` per estrarre un singolo elemento: per esempio, `heroes.loc['Superman', 'Strength']` equivale alla prima delle due istruzioni appena elencate. Tuttavia, `at` e `iat` sono implementate in modo da essere più efficienti.
# </div>
#
# È infine possibile riordinare le righe di un dataframe invocando i metodi `sort_values` e `sort_index`: il primo basa l'ordinamento sul valore di una colonna, il cui nome va specificato tramite l'argomento `by` e il secondo è invece basato sui valori dell'indice. È inoltre possibile indicare un valore booleano per l'argomento `ascending` che permette di ordinare in verso crescente o decrescente.

# %%
heroes.sort_values(by='Weight', ascending=False)[:5]
# Out:
#                      Identity                 Birth place      Publisher  \
# Name
# Sasquatch   Walter Langkowski  Edmonton, Alberta, Canada   Marvel Comics
# Juggernaut         Cain Marko        Berkeley, California  Marvel Comics
# Darkseid                 Uxas                         NaN      DC Comics
# Hulk             Bruce Banner                Dayton, Ohio  Marvel Comics
# Giganta            Doris Zuel                         NaN      DC Comics
#
#             Height  Weight Gender  First appearance Eye color Hair color  \
# Name
# Sasquatch   305.02  900.70      M               NaN       Red     Orange
# Juggernaut  287.95  855.82      M            1965.0      Blue        Red
# Darkseid    267.37  817.57      M            1970.0       Red    No Hair
# Hulk        244.40  630.90      M            1962.0     Green      Green
# Giganta      62.65  630.80      F            1944.0     Green        Red
#
#             Strength Intelligence
# Name
# Sasquatch       80.0         good
# Juggernaut     100.0      average
# Darkseid       100.0         high
# Hulk           100.0         high
# Giganta         90.0         high

# %%
heroes.sort_index()[-5:]
# Out:
#                        Identity Birth place      Publisher  Height  Weight  \
# Name
# Yellowjacket II     Rita DeMara         NaN  Marvel Comics  165.58   52.36
# Ymir                       Ymir  Niffleheim  Marvel Comics  304.63     NaN
# Yoda                       Yoda         NaN   George Lucas   66.29   17.01
# Zatanna          Zatanna Zatara         NaN      DC Comics  170.29   57.77
# Zoom             Hunter Zolomon         NaN      DC Comics  185.90   81.93
#
#                 Gender  First appearance Eye color        Hair color  \
# Name
# Yellowjacket II      F               NaN      Blue  Strawberry Blond
# Ymir                 M               NaN     White           No Hair
# Yoda                 M            1980.0     Brown             White
# Zatanna              F               NaN      Blue             Black
# Zoom                 M               NaN       Red             Brown
#
#                  Strength Intelligence
# Name
# Yellowjacket II      10.0      average
# Ymir                100.0      average
# Yoda                 55.0         high
# Zatanna              10.0         high
# Zoom                 10.0      average

# %% [markdown]
# Va notato che entrmabi i metodi restituiscono una copia del _dataframe_. Anche per i _dataframe_ è possibile utilizzare una lista di valori booleani che identificano le righe da selezionare, e tale lista può essere prodotta effettuando una query. In questo caso però le condizioni possono riguardare le varie colonne, ognuna delle quali va specificata usando una delle due sintassi precedentemente introdotte (quella analoga ai dizionari oppure quella basata su _dot notation_). Per esempio possiamo selezionare gli eroi per cui l'anno di apparizione esiste e rappresenta un valore non fuori scala nel modo seguente:

# %% [markdown]
# Si un braodcasting per avere una serie di booleani per accedere a `heroes` come *dataframe*. così sto facendo una query all'interno del mio *dataframe*.

# %%
heroes_with_year = heroes[heroes['First appearance'] > 1900] #quando il mio valore in first_appearance > 1900. Posso farlo anche con altri valori per esempio il colore degli occhi
heroes_with_year.head()
# Out:
#                           Identity         Birth place          Publisher  \
# Name
# A-Bomb      Richard Milhouse Jones  Scarsdale, Arizona      Marvel Comics
# Agent Bob                      Bob                 NaN      Marvel Comics
# Abe Sapien          Abraham Sapien                 NaN  Dark Horse Comics
# Abin Sur                       NaN              Ungara          DC Comics
# Animal Man          Bernhard Baker                 NaN          DC Comics
#
#             Height  Weight Gender  First appearance Eye color Hair color  \
# Name
# A-Bomb      203.21  441.95      M            2008.0    Yellow    No Hair
# Agent Bob   178.25   81.45      M            2007.0     Brown      Brown
# Abe Sapien  191.24   65.35      M            1993.0      Blue    No Hair
# Abin Sur    185.52   90.90      M            1959.0      Blue    No Hair
# Animal Man  183.80   83.39      M            1965.0      Blue      Blond
#
#             Strength Intelligence
# Name
# A-Bomb         100.0     moderate
# Agent Bob       10.0          low
# Abe Sapien      30.0         high
# Abin Sur        90.0      average
# Animal Man      50.0      average

# %%
heroes_with_blue_eyes = heroes[heroes['Eye color'] == 'Blue']
heroes_with_blue_eyes
# Out:
#                                            Identity  \
# Name
# Abraxas                                     Abraxas
# Adam Monroe                                     NaN
# Agent 13                              Sharon Carter
# Air-Walker                              Gabriel Lan
# Abe Sapien                           Abraham Sapien
# ...                                             ...
# Angel                Warren Kenneth Worthington III
# Arachne                             Julia Carpenter
# Alfred Pennyworth  Alfred Thaddeus Crane Pennyworth
# Alan Scott               Alan Ladd Wellington Scott
# Ant-Man                                    Hank Pym
#
#                                                          Birth place  \
# Name
# Abraxas                                             Within Eternity
# Adam Monroe                                                      NaN
# Agent 13                                                         NaN
# Air-Walker         Xandar, a planet in the Tranta system, Androme...
# Abe Sapien                                                       NaN
# ...                                                              ...
# Angel                             Centerport, Long Island, New York
# Arachne                                      Los Angeles, California
# Alfred Pennyworth                                                NaN
# Alan Scott                                               Gotham City
# Ant-Man                                           Elmsford, New York
#
#                            Publisher  Height  Weight Gender  First appearance  \
# Name
# Abraxas                Marvel Comics     NaN     NaN      M               NaN
# Adam Monroe             NBC - Heroes     NaN     NaN      M               NaN
# Agent 13               Marvel Comics  173.41   61.03      F               NaN
# Air-Walker             Marvel Comics  188.59  108.23      M               NaN
# Abe Sapien         Dark Horse Comics  191.24   65.35      M            1993.0
# ...                              ...     ...     ...    ...               ...
# Angel                  Marvel Comics  183.05   68.99      M            1969.0
# Arachne                Marvel Comics  175.15   63.75      F               NaN
# Alfred Pennyworth          DC Comics  178.26   72.98      M            1943.0
# Alan Scott                 DC Comics  180.98   90.81      M            1940.0
# Ant-Man                Marvel Comics  211.74  122.44      M            1962.0
#
#                   Eye color Hair color  Strength Intelligence
# Name
# Abraxas                Blue      Black     100.0         high
# Adam Monroe            Blue      Blond      10.0         good
# Agent 13               Blue      Blond       NaN          NaN
# Air-Walker             Blue      White      85.0      average
# Abe Sapien             Blue    No Hair      30.0         high
# ...                     ...        ...       ...          ...
# Angel                  Blue      Blond      15.0         good
# Arachne                Blue      Blond      50.0      average
# Alfred Pennyworth      Blue      Black      10.0         good
# Alan Scott             Blue      Blond      80.0         good
# Ant-Man                Blue      Blond      20.0         high
#
# [219 rows x 11 columns]

# %% [markdown]
# <hr style="width: 90%;" align="left" />
# <span style="font-size: 0.8rem;">D. Malchiodi, Superhero data science. Vol 1: probabilità e statistica: Pandas, 2017.</span>
# <br>
# <span style="font-size: 0.8rem;">Powered by <img src="img/jupyter-logo.png" style="height: 1rem; display: inline; margin-left: 0.5ex; margin-top: 0;" alt="Jupyter Notebook"></span>
# <div style="float: left; margin-top: 1ex;">
# <img src="http://mirrors.creativecommons.org/presskit/icons/cc.large.png" style="width: 1.5em; float: left; margin-right: 0.6ex; margin-top: 0;">
# <img src="http://mirrors.creativecommons.org/presskit/icons/by.large.png" style="width: 1.5em; float: left; margin-right: 0.6ex; margin-top: 0;">
# <img src="http://mirrors.creativecommons.org/presskit/icons/nc.large.png" style="width: 1.5em; float: left; margin-right: 0.6ex; margin-top: 0;">
# <img src="http://mirrors.creativecommons.org/presskit/icons/nd.large.png" style="width: 1.5em; float: left; margin-right: 0.6ex; margin-top: 0;">
# <span style="font-size: 0.7rem; line-height: 0.7rem; vertical-align: middle;">Quest'opera è distribuita con Licenza <a rel="license" href="http://creativecommons.org/licenses/by-nc-nd/4.0/">Creative Commons Attribuzione - Non commerciale - Non opere derivate 4.0 Internazionale</a></span>.
# </div>
